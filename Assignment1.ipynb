# %% [markdown]
# # FDU PRML 2024 Fall Assignment 1
#
# Name: `徐一冉`
#
# Student ID: `22307130487`

# %% [markdown]
# Please follow the instructions and complete the following exercises using PyTorch.
#
# ## 1. Basic Operations of Tensors

# %%
import torch

my_first_tensor = torch.ones(3,4)  # TODO: assign a tensor of shape (3, 4) with all elements equal to 1.0

my_second_tensor = torch.randn(3,4) # TODO: assign a random tensor of shape (3, 4) with all elements sampled from a standard normal distribution

their_matrix_product = my_first_tensor @ my_second_tensor.T  # TODO: compute the matrix product of my_first_tensor and the transpose of my_second_tensor (There are multiple ways to do this. Just pick one you like.)

some_meaningless_concatenation = torch.cat([my_first_tensor, my_second_tensor], dim=0)  # TODO: concatenate my_first_tensor and my_second_tensor along the first dimension. (Maybe you should check the documentation of torch.cat)

some_meaningless_stack = torch.stack([my_first_tensor] *5, dim =0)  # TODO: stack 5 copies of my_first_tensor along a newly created dimension. (Maybe you should check the documentation of torch.stack)

# What is the shape of some_meaningless_stack? Can you imagine the geometric interpretation of stacking 5 matrices of shape (3, 4) along the first dimension?

# %% [markdown]
# ## 2. A simple logistic regression
#
# There are 4 core components in Pytorch training process: **model**, **loss function**, **optimizer** and **data loader**. In this part, we will implement a simple logistic regression model to illustrate them.
#
# ### 2.1 Model and Loss Function

# %%
# Define a linear layer for logitstic regression

class Linear(torch.nn.Module):
	def __init__(self, input_dim, output_dim):
		super().__init__()
		# pass
		# TODO: initialize the weight and bias of the linear layer.
		self.weight = torch.nn.Parameter(torch.randn(input_dim, output_dim))
		self.bias = torch.nn.Parameter(torch.zeros(output_dim))
  
	def forward(self, x):
		# pass
		# TODO: implement the forward function of a linear layer.
		return x @ self.weight + self.bias


def loss_function(y_pred, y):
    # TODO: implement the loss function of logistic regression.
    # pass
	return torch.nn.functional.binary_cross_entropy_with_logits(y_pred.squeeze(), y)

# %% [markdown]
# ### Synthetic Data
#
# In real world, we usually have to deal with large-scale datasets. However, in this assignment, we will use synthetic data to illustrate the training process. The synthetic data is generated by the following function:

# %%
# Generate some random data for binary classification

num_samples = 100
num_features = 2

x_0 = torch.randn(num_samples, num_features) + torch.tensor([2.0, 2.0])
y_0 = torch.zeros(num_samples)

x_1 = torch.randn(num_samples, num_features) + torch.tensor([-2.0, -2.0])
y_1 = torch.ones(num_samples)

x = torch.cat([x_0, x_1], dim=0)
y = torch.cat([y_0, y_1], dim=0)

# %% [markdown]
# ### 2.2 Dataloader

# %%
# Define a dataset to feed into the model

class MyDataset(torch.utils.data.Dataset):
	def __init__(self, x, y):
		super().__init__()
		self.x = x
		self.y = y

	def __getitem__(self, index):
		# TODO: implement the __getitem__ function.
		# pass
		return self.x[index], self.y[index]

	def __len__(self):
		# TODO: implement the __len__ function.
		# pass
		return len(self.x) 

dataset = MyDataset(x, y)
dataloder = torch.utils.data.DataLoader(dataset, batch_size=16, shuffle=True)

# %% [markdown]
# ### 2.3 Optimizer

# %%
my_model = Linear(num_features, 1)

optimizer =  torch.optim.Adam(my_model.parameters(), lr=0.01)  # TODO: initialize an optimizer of your choice.

# %% [markdown]
# ### Putting all together
#
# Since this is just a toy experiment, we do not need validation.
#
# In the following code, we expect to see the training loss decreasing to 0.001 or lower.

# %%
# Train the model

for epoch in range(100):
	for batch_x, batch_y in dataloder:
		# TODO: implement the training loop.
		# pass
		optimizer.zero_grad()
		pred = my_model(batch_x)
		loss = loss_function(pred, batch_y)
		loss.backward()
		optimizer.step()
  
	if epoch % 10 == 0:
		print('epoch: {}, loss: {}'.format(epoch, loss.item()))
  
# save the model

torch.save(my_model.state_dict(), 'my_model.pt')
# Out:
# epoch: 0, loss: 1.2072618007659912
# epoch: 10, loss: 0.1462070494890213
# epoch: 20, loss: 0.029419932514429092
# epoch: 30, loss: 0.09361959248781204
# epoch: 40, loss: 0.016517918556928635
# epoch: 50, loss: 0.05103921517729759
# epoch: 60, loss: 0.018556121736764908
# epoch: 70, loss: 0.017881684005260468
# epoch: 80, loss: 0.011547241359949112
# epoch: 90, loss: 0.02400272898375988

# %% [markdown]
# ## 3. MNIST Classification
# MLP 数据集分类
#
# In this section, you will use PyTorch to implement a multi-layer perceptron (MLP) model for classifying handwritten digits using the MNIST dataset.
#
#
# 1. Data Loading and Preprocessing:
#    - Utilize the `torchvision.datasets` module to load the MNIST dataset.
#    - Apply necessary transformations (like `ToTensor` and `Normalize`) to prepare the data for model training. These transformations ensure the data has the correct format and scales, helping with model convergence.
#    - Use a DataLoader with a suitable batch size to efficiently manage data feeding into the model.
#
# 2. Architecture:
#    - Define a simple MLP model with PyTorch's `torch.nn.Module`. A suggested architecture is:
#      - An input layer that takes the flattened 28x28 pixel values (784 features).
#      - One or more hidden layers with ReLU activations for non-linearity.
#      - An output layer with softmax activation for multi-class classification.
#    - Make sure to initialize the model appropriately, especially if you're stacking multiple layers.
#
# 3. Training:
#    - Set up an optimizer (like `Adam` or `SGD`) to minimize the model's error during training. You will also need a loss function, such as `CrossEntropyLoss`, which is well-suited for classification tasks.
#    - Write a training loop that performs the following steps:
#      - Forward pass: Feed batches through the model to obtain predictions.
#      - Compute the loss by comparing predictions with true labels.
#      - Backward pass: Calculate gradients for each model parameter.
#      - Update the model weights using the optimizer.
#    - Periodically log or print the training loss to track progress.
#
# 4. Evaluation:
#    - After training, evaluate your model on the test set.
#    - Compute and print the accuracy metric, and optionally, create a confusion matrix to analyze classification errors.
#
#
# MNIST: http://yann.lecun.com/exdb/mnist/

# %%
from torchvision import datasets, transforms

transform=transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.1307,), (0.3081,))
    ])
dataset1 = datasets.MNIST('./data', train=True, download=True,
                    transform=transform)
dataset2 = datasets.MNIST('./data', train=False,
                    transform=transform)
train_loader = torch.utils.data.DataLoader(dataset1)
test_loader = torch.utils.data.DataLoader(dataset2)

# %%
class MLP(torch.nn.Module):
    def __init__(self):
        super().__init__()
        self.flatten = torch.nn.Flatten()
        self.layers = torch.nn.Sequential(
            torch.nn.Linear(28 * 28, 512),
            torch.nn.ReLU(),
            torch.nn.Linear(512, 256),
            torch.nn.ReLU(),
            torch.nn.Linear(256, 10)
        )
    
    def forward(self, x):
        x = self.flatten(x)
        return self.layers(x)

# 初始化模型、损失函数和优化器
model = MLP()
criterion = torch.nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

# 训练循环
def train(model, train_loader, criterion, optimizer):
    model.train()
    for batch_idx, (data, target) in enumerate(train_loader):
        optimizer.zero_grad()
        output = model(data)
        loss = criterion(output, target)
        loss.backward()
        optimizer.step()
        
        if batch_idx % 100 == 0:
            print(f'Train Batch: {batch_idx}, Loss: {loss.item():.4f}')

# 评估函数
def evaluate(model, test_loader):
    model.eval()
    correct = 0
    total = 0
    with torch.no_grad():
        for data, target in test_loader:
            output = model(data)
            _, predicted = torch.max(output.data, 1)
            total += target.size(0)
            correct += (predicted == target).sum().item()
    
    accuracy = 100 * correct / total
    print(f'Test Accuracy: {accuracy:.2f}%')
    return accuracy

# 训练模型
num_epochs = 5
for epoch in range(num_epochs):
    print(f'Epoch {epoch+1}/{num_epochs}')
    train(model, train_loader, criterion, optimizer)
    evaluate(model, test_loader)
# Out:
# Epoch 1/5
# Train Batch: 0, Loss: 2.1812
# Train Batch: 100, Loss: 3.0872
# Train Batch: 200, Loss: 0.1913
# Train Batch: 300, Loss: 2.3751
# Train Batch: 400, Loss: 0.0019
# Train Batch: 500, Loss: 4.0902
# Train Batch: 600, Loss: 0.0297
# Train Batch: 700, Loss: 0.0136
# Train Batch: 800, Loss: 0.0057
# Train Batch: 900, Loss: 0.3897
# Train Batch: 1000, Loss: 0.2384
# Train Batch: 1100, Loss: 0.1768
# Train Batch: 1200, Loss: 0.0017
# Train Batch: 1300, Loss: 0.0427
# Train Batch: 1400, Loss: 0.7647
# Train Batch: 1500, Loss: 3.4802
# Train Batch: 1600, Loss: 1.9543
# Train Batch: 1700, Loss: 0.0002
# Train Batch: 1800, Loss: 0.0007
# Train Batch: 1900, Loss: 0.0572
# Train Batch: 2000, Loss: 1.7357
# Train Batch: 2100, Loss: 0.0000
# Train Batch: 2200, Loss: 0.3284
# Train Batch: 2300, Loss: 0.0001
# Train Batch: 2400, Loss: 0.0001
# Train Batch: 2500, Loss: 0.0001
# Train Batch: 2600, Loss: 0.7976
# Train Batch: 2700, Loss: 0.0058
# Train Batch: 2800, Loss: 0.7353
# Train Batch: 2900, Loss: 0.1388
# Train Batch: 3000, Loss: 0.5718
# Train Batch: 3100, Loss: 0.4779
# Train Batch: 3200, Loss: 1.1635
# Train Batch: 3300, Loss: 0.0013
# Train Batch: 3400, Loss: 0.0045
# Train Batch: 3500, Loss: 0.0523
# Train Batch: 3600, Loss: 0.0816
# Train Batch: 3700, Loss: 0.0126
# Train Batch: 3800, Loss: 0.0053
# Train Batch: 3900, Loss: 0.0113
# Train Batch: 4000, Loss: 0.0010
# Train Batch: 4100, Loss: 0.0006
# Train Batch: 4200, Loss: 0.0000
# Train Batch: 4300, Loss: 0.0012
# Train Batch: 4400, Loss: 0.0038
# Train Batch: 4500, Loss: 2.6175
# Train Batch: 4600, Loss: 0.0169
# Train Batch: 4700, Loss: 0.1166
# Train Batch: 4800, Loss: 1.9263
# Train Batch: 4900, Loss: 0.0000
# Train Batch: 5000, Loss: 1.3062
# Train Batch: 5100, Loss: 0.0000
# Train Batch: 5200, Loss: 0.9937
# Train Batch: 5300, Loss: 0.0000
# Train Batch: 5400, Loss: 0.0106
# Train Batch: 5500, Loss: 0.0000
# Train Batch: 5600, Loss: 1.7191
# Train Batch: 5700, Loss: 0.0271
# Train Batch: 5800, Loss: 0.9232
# Train Batch: 5900, Loss: 0.0004
# Train Batch: 6000, Loss: 0.0000
# Train Batch: 6100, Loss: 1.4276
# Train Batch: 6200, Loss: 0.5947
# Train Batch: 6300, Loss: 0.0189
# Train Batch: 6400, Loss: 0.0000
# Train Batch: 6500, Loss: 0.1291
# Train Batch: 6600, Loss: 2.4458
# Train Batch: 6700, Loss: 0.0000
# Train Batch: 6800, Loss: 0.0012
# Train Batch: 6900, Loss: 0.0000
# Train Batch: 7000, Loss: 0.0750
# Train Batch: 7100, Loss: 0.0628
# Train Batch: 7200, Loss: 0.2511
# Train Batch: 7300, Loss: 1.4609
# Train Batch: 7400, Loss: 0.1919
# Train Batch: 7500, Loss: 0.0000
# Train Batch: 7600, Loss: 0.0339
# Train Batch: 7700, Loss: 0.2926
# Train Batch: 7800, Loss: 0.0232
# Train Batch: 7900, Loss: 1.8678
# Train Batch: 8000, Loss: 0.0000
# Train Batch: 8100, Loss: 0.0000
# Train Batch: 8200, Loss: 2.6005
# Train Batch: 8300, Loss: 2.7253
# Train Batch: 8400, Loss: 0.0031
# Train Batch: 8500, Loss: 0.0000
# Train Batch: 8600, Loss: 1.7849
# Train Batch: 8700, Loss: 0.4302
# Train Batch: 8800, Loss: 0.0955
# Train Batch: 8900, Loss: 0.0000
# Train Batch: 9000, Loss: 0.0002
# Train Batch: 9100, Loss: 0.0000
# Train Batch: 9200, Loss: 0.0013
# Train Batch: 9300, Loss: 0.0000
# Train Batch: 9400, Loss: 0.0001
# Train Batch: 9500, Loss: 0.0000
# Train Batch: 9600, Loss: 0.0000
# Train Batch: 9700, Loss: 0.0001
# Train Batch: 9800, Loss: 0.6173
# Train Batch: 9900, Loss: 0.0006
# Train Batch: 10000, Loss: 0.0000
# Train Batch: 10100, Loss: 0.0155
# Train Batch: 10200, Loss: 0.0056
# Train Batch: 10300, Loss: 0.0201
# Train Batch: 10400, Loss: 0.0542
# Train Batch: 10500, Loss: 0.0125
# Train Batch: 10600, Loss: 0.0020
# Train Batch: 10700, Loss: 0.0001
# Train Batch: 10800, Loss: 0.2284
# Train Batch: 10900, Loss: 0.0000
# Train Batch: 11000, Loss: 0.0001
# Train Batch: 11100, Loss: 0.7240
# Train Batch: 11200, Loss: 0.0001
# Train Batch: 11300, Loss: 0.0000
# Train Batch: 11400, Loss: 0.0261
# Train Batch: 11500, Loss: 0.0477
# Train Batch: 11600, Loss: 0.7613
# Train Batch: 11700, Loss: 0.0191
# Train Batch: 11800, Loss: 0.0000
# Train Batch: 11900, Loss: 0.1334
# Train Batch: 12000, Loss: 0.0039
# Train Batch: 12100, Loss: 0.0000
# Train Batch: 12200, Loss: 0.0129
# Train Batch: 12300, Loss: 0.0001
# Train Batch: 12400, Loss: 0.0013
# Train Batch: 12500, Loss: 0.0003
# Train Batch: 12600, Loss: 0.0786
# Train Batch: 12700, Loss: 0.0010
# Train Batch: 12800, Loss: 0.0049
# Train Batch: 12900, Loss: 2.6208
# Train Batch: 13000, Loss: 0.0230
# Train Batch: 13100, Loss: 0.6916
# Train Batch: 13200, Loss: 0.1614
# Train Batch: 13300, Loss: 0.0029
# Train Batch: 13400, Loss: 0.3765
# Train Batch: 13500, Loss: 0.0053
# Train Batch: 13600, Loss: 0.0000
# Train Batch: 13700, Loss: 0.0005
# Train Batch: 13800, Loss: 0.0034
# Train Batch: 13900, Loss: 0.0254
# Train Batch: 14000, Loss: 0.0000
# Train Batch: 14100, Loss: 2.3580
# Train Batch: 14200, Loss: 0.0302
# Train Batch: 14300, Loss: 0.0000
# Train Batch: 14400, Loss: 0.0003
# Train Batch: 14500, Loss: 0.5821
# Train Batch: 14600, Loss: 0.0000
# Train Batch: 14700, Loss: 1.9048
# Train Batch: 14800, Loss: 0.0386
# Train Batch: 14900, Loss: 0.0006
# Train Batch: 15000, Loss: 0.0038
# Train Batch: 15100, Loss: 0.0023
# Train Batch: 15200, Loss: 0.0000
# Train Batch: 15300, Loss: 0.0006
# Train Batch: 15400, Loss: 0.0247
# Train Batch: 15500, Loss: 0.2172
# Train Batch: 15600, Loss: 0.0000
# Train Batch: 15700, Loss: 0.0000
# Train Batch: 15800, Loss: 0.0000
# Train Batch: 15900, Loss: 0.0000
# Train Batch: 16000, Loss: 0.0000
# Train Batch: 16100, Loss: 5.0492
# Train Batch: 16200, Loss: 0.0008
# Train Batch: 16300, Loss: 0.0000
# Train Batch: 16400, Loss: 0.0006
# Train Batch: 16500, Loss: 0.0000
# Train Batch: 16600, Loss: 0.1561
# Train Batch: 16700, Loss: 0.6841
# Train Batch: 16800, Loss: 0.0000
# Train Batch: 16900, Loss: 0.0023
# Train Batch: 17000, Loss: 0.1063
# Train Batch: 17100, Loss: 0.1277
# Train Batch: 17200, Loss: 2.8093
# Train Batch: 17300, Loss: 0.1733
# Train Batch: 17400, Loss: 0.0077
# Train Batch: 17500, Loss: 0.0423
# Train Batch: 17600, Loss: 3.9333
# Train Batch: 17700, Loss: 0.6130
# Train Batch: 17800, Loss: 0.0000
# Train Batch: 17900, Loss: 0.0000
# Train Batch: 18000, Loss: 0.0000
# Train Batch: 18100, Loss: 0.0000
# Train Batch: 18200, Loss: 0.0023
# Train Batch: 18300, Loss: 0.0000
# Train Batch: 18400, Loss: 0.0000
# Train Batch: 18500, Loss: 0.0034
# Train Batch: 18600, Loss: 0.0002
# Train Batch: 18700, Loss: 0.9624
# Train Batch: 18800, Loss: 0.0000
# Train Batch: 18900, Loss: 2.2842
# Train Batch: 19000, Loss: 0.0251
# Train Batch: 19100, Loss: 0.0000
# Train Batch: 19200, Loss: 0.0000
# Train Batch: 19300, Loss: 0.4024
# Train Batch: 19400, Loss: 0.0004
# Train Batch: 19500, Loss: 0.0000
# Train Batch: 19600, Loss: 0.0134
# Train Batch: 19700, Loss: 0.0000
# Train Batch: 19800, Loss: 0.0000
# Train Batch: 19900, Loss: 0.0000
# Train Batch: 20000, Loss: 0.0000
# Train Batch: 20100, Loss: 0.1518
# Train Batch: 20200, Loss: 0.0000
# Train Batch: 20300, Loss: 2.0478
# Train Batch: 20400, Loss: 0.0000
# Train Batch: 20500, Loss: 0.0189
# Train Batch: 20600, Loss: 0.9512
# Train Batch: 20700, Loss: 0.0000
# Train Batch: 20800, Loss: 0.0011
# Train Batch: 20900, Loss: 0.0789
# Train Batch: 21000, Loss: 0.0443
# Train Batch: 21100, Loss: 0.0105
# Train Batch: 21200, Loss: 0.0000
# Train Batch: 21300, Loss: 0.0001
# Train Batch: 21400, Loss: 0.0000
# Train Batch: 21500, Loss: 0.0204
# Train Batch: 21600, Loss: 0.0000
# Train Batch: 21700, Loss: 3.5655
# Train Batch: 21800, Loss: 0.0000
# Train Batch: 21900, Loss: 0.0000
# Train Batch: 22000, Loss: 0.0008
# Train Batch: 22100, Loss: 0.0010
# Train Batch: 22200, Loss: 0.3027
# Train Batch: 22300, Loss: 0.0000
# Train Batch: 22400, Loss: 0.2483
# Train Batch: 22500, Loss: 0.0000
# Train Batch: 22600, Loss: 0.0000
# Train Batch: 22700, Loss: 0.0000
# Train Batch: 22800, Loss: 0.0002
# Train Batch: 22900, Loss: 0.0000
# Train Batch: 23000, Loss: 0.0000
# Train Batch: 23100, Loss: 0.4187
# Train Batch: 23200, Loss: 0.0000
# Train Batch: 23300, Loss: 0.0016
# Train Batch: 23400, Loss: 5.3026
# Train Batch: 23500, Loss: 0.0998
# Train Batch: 23600, Loss: 0.0010
# Train Batch: 23700, Loss: 0.0002
# Train Batch: 23800, Loss: 0.0000
# Train Batch: 23900, Loss: 0.0000
# Train Batch: 24000, Loss: 0.0001
# Train Batch: 24100, Loss: 0.0000
# Train Batch: 24200, Loss: 0.0000
# Train Batch: 24300, Loss: 1.7514
# Train Batch: 24400, Loss: 0.0023
# Train Batch: 24500, Loss: 0.0000
# Train Batch: 24600, Loss: 0.0000
# Train Batch: 24700, Loss: 0.0000
# Train Batch: 24800, Loss: 0.0001
# Train Batch: 24900, Loss: 0.0038
# Train Batch: 25000, Loss: 3.6709
# Train Batch: 25100, Loss: 0.0005
# Train Batch: 25200, Loss: 0.1344
# Train Batch: 25300, Loss: 0.0003
# Train Batch: 25400, Loss: 0.0843
# Train Batch: 25500, Loss: 0.0000
# Train Batch: 25600, Loss: 0.0000
# Train Batch: 25700, Loss: 0.0000
# Train Batch: 25800, Loss: 9.2694
# Train Batch: 25900, Loss: 0.3876
# Train Batch: 26000, Loss: 0.0015
# Train Batch: 26100, Loss: 0.0047
# Train Batch: 26200, Loss: 0.0000
# Train Batch: 26300, Loss: 3.9148
# Train Batch: 26400, Loss: 0.0007
# Train Batch: 26500, Loss: 0.0006
# Train Batch: 26600, Loss: 1.3047
# Train Batch: 26700, Loss: 0.1201
# Train Batch: 26800, Loss: 0.0000
# Train Batch: 26900, Loss: 1.1487
# Train Batch: 27000, Loss: 0.8009
# Train Batch: 27100, Loss: 0.0000
# Train Batch: 27200, Loss: 0.1001
# Train Batch: 27300, Loss: 0.0001
# Train Batch: 27400, Loss: 0.0000
# Train Batch: 27500, Loss: 0.0001
# Train Batch: 27600, Loss: 0.0000
# Train Batch: 27700, Loss: 1.0698
# Train Batch: 27800, Loss: 0.0009
# Train Batch: 27900, Loss: 0.0001
# Train Batch: 28000, Loss: 0.0000
# Train Batch: 28100, Loss: 0.0000
# Train Batch: 28200, Loss: 0.2365
# Train Batch: 28300, Loss: 0.0000
# Train Batch: 28400, Loss: 0.0000
# Train Batch: 28500, Loss: 0.0000
# Train Batch: 28600, Loss: 0.0083
# Train Batch: 28700, Loss: 0.0007
# Train Batch: 28800, Loss: 0.0000
# Train Batch: 28900, Loss: 0.1960
# Train Batch: 29000, Loss: 0.0023
# Train Batch: 29100, Loss: 0.0007
# Train Batch: 29200, Loss: 0.0010
# Train Batch: 29300, Loss: 0.1656
# Train Batch: 29400, Loss: 0.0000
# Train Batch: 29500, Loss: 1.1029
# Train Batch: 29600, Loss: 0.0060
# Train Batch: 29700, Loss: 0.3335
# Train Batch: 29800, Loss: 0.0522
# Train Batch: 29900, Loss: 0.4663
# Train Batch: 30000, Loss: 0.0000
# Train Batch: 30100, Loss: 0.0000
# Train Batch: 30200, Loss: 0.0000
# Train Batch: 30300, Loss: 0.0000
# Train Batch: 30400, Loss: 0.0001
# Train Batch: 30500, Loss: 0.0145
# Train Batch: 30600, Loss: 0.0450
# Train Batch: 30700, Loss: 0.0001
# Train Batch: 30800, Loss: 0.0000
# Train Batch: 30900, Loss: 2.9113
# Train Batch: 31000, Loss: 0.0762
# Train Batch: 31100, Loss: 0.0002
# Train Batch: 31200, Loss: 0.0000
# Train Batch: 31300, Loss: 0.0009
# Train Batch: 31400, Loss: 0.1016
# Train Batch: 31500, Loss: 0.1581
# Train Batch: 31600, Loss: 1.7025
# Train Batch: 31700, Loss: 0.2683
# Train Batch: 31800, Loss: 0.0108
# Train Batch: 31900, Loss: 0.0214
# Train Batch: 32000, Loss: 0.0006
# Train Batch: 32100, Loss: 0.6637
# Train Batch: 32200, Loss: 0.0012
# Train Batch: 32300, Loss: 0.0022
# Train Batch: 32400, Loss: 0.0000
# Train Batch: 32500, Loss: 0.1028
# Train Batch: 32600, Loss: 0.0000
# Train Batch: 32700, Loss: 0.0089
# Train Batch: 32800, Loss: 0.0000
# Train Batch: 32900, Loss: 0.0000
# Train Batch: 33000, Loss: 4.1443
# Train Batch: 33100, Loss: 0.0000
# Train Batch: 33200, Loss: 0.5863
# Train Batch: 33300, Loss: 0.0076
# Train Batch: 33400, Loss: 0.0000
# Train Batch: 33500, Loss: 0.0000
# Train Batch: 33600, Loss: 0.0021
# Train Batch: 33700, Loss: 0.0003
# Train Batch: 33800, Loss: 0.0002
# Train Batch: 33900, Loss: 0.0008
# Train Batch: 34000, Loss: 0.0017
# Train Batch: 34100, Loss: 0.1085
# Train Batch: 34200, Loss: 0.0013
# Train Batch: 34300, Loss: 1.0821
# Train Batch: 34400, Loss: 0.0000
# Train Batch: 34500, Loss: 4.9029
# Train Batch: 34600, Loss: 0.0040
# Train Batch: 34700, Loss: 0.0065
# Train Batch: 34800, Loss: 3.0557
# Train Batch: 34900, Loss: 0.0003
# Train Batch: 35000, Loss: 0.0000
# Train Batch: 35100, Loss: 0.0155
# Train Batch: 35200, Loss: 0.0000
# Train Batch: 35300, Loss: 0.0248
# Train Batch: 35400, Loss: 0.0000
# Train Batch: 35500, Loss: 0.0000
# Train Batch: 35600, Loss: 0.0000
# Train Batch: 35700, Loss: 0.0000
# Train Batch: 35800, Loss: 0.0000
# Train Batch: 35900, Loss: 0.0000
# Train Batch: 36000, Loss: 0.0132
# Train Batch: 36100, Loss: 0.0000
# Train Batch: 36200, Loss: 0.0293
# Train Batch: 36300, Loss: 0.0031
# Train Batch: 36400, Loss: 0.0001
# Train Batch: 36500, Loss: 0.0037
# Train Batch: 36600, Loss: 0.0000
# Train Batch: 36700, Loss: 0.0009
# Train Batch: 36800, Loss: 0.0090
# Train Batch: 36900, Loss: 2.6602
# Train Batch: 37000, Loss: 0.0000
# Train Batch: 37100, Loss: 1.0559
# Train Batch: 37200, Loss: 0.0000
# Train Batch: 37300, Loss: 0.0000
# Train Batch: 37400, Loss: 0.1454
# Train Batch: 37500, Loss: 0.0016
# Train Batch: 37600, Loss: 0.0029
# Train Batch: 37700, Loss: 0.0000
# Train Batch: 37800, Loss: 0.0000
# Train Batch: 37900, Loss: 0.0000
# Train Batch: 38000, Loss: 0.5734
# Train Batch: 38100, Loss: 0.0001
# Train Batch: 38200, Loss: 0.0000
# Train Batch: 38300, Loss: 0.0001
# Train Batch: 38400, Loss: 0.0000
# Train Batch: 38500, Loss: 0.0001
# Train Batch: 38600, Loss: 0.0000
# Train Batch: 38700, Loss: 3.6969
# Train Batch: 38800, Loss: 0.0462
# Train Batch: 38900, Loss: 0.0000
# Train Batch: 39000, Loss: 0.8261
# Train Batch: 39100, Loss: 0.0000
# Train Batch: 39200, Loss: 0.0000
# Train Batch: 39300, Loss: 0.0000
# Train Batch: 39400, Loss: 0.0000
# Train Batch: 39500, Loss: 1.5809
# Train Batch: 39600, Loss: 4.3717
# Train Batch: 39700, Loss: 0.0000
# Train Batch: 39800, Loss: 0.0000
# Train Batch: 39900, Loss: 0.0000
# Train Batch: 40000, Loss: 0.0013
# Train Batch: 40100, Loss: 0.0685
# Train Batch: 40200, Loss: 0.0000
# Train Batch: 40300, Loss: 0.3447
# Train Batch: 40400, Loss: 0.0000
# Train Batch: 40500, Loss: 0.0061
# Train Batch: 40600, Loss: 0.0091
# Train Batch: 40700, Loss: 0.0224
# Train Batch: 40800, Loss: 0.2076
# Train Batch: 40900, Loss: 0.1489
# Train Batch: 41000, Loss: 0.0000
# Train Batch: 41100, Loss: 0.0000
# Train Batch: 41200, Loss: 0.0644
# Train Batch: 41300, Loss: 1.9118
# Train Batch: 41400, Loss: 0.0005
# Train Batch: 41500, Loss: 0.0123
# Train Batch: 41600, Loss: 0.0000
# Train Batch: 41700, Loss: 0.0406
# Train Batch: 41800, Loss: 0.0002
# Train Batch: 41900, Loss: 0.0003
# Train Batch: 42000, Loss: 0.0000
# Train Batch: 42100, Loss: 0.0000
# Train Batch: 42200, Loss: 0.0000
# Train Batch: 42300, Loss: 0.0000
# Train Batch: 42400, Loss: 0.0013
# Train Batch: 42500, Loss: 0.0093
# Train Batch: 42600, Loss: 0.0000
# Train Batch: 42700, Loss: 0.0000
# Train Batch: 42800, Loss: 0.0459
# Train Batch: 42900, Loss: 0.3880
# Train Batch: 43000, Loss: 0.0738
# Train Batch: 43100, Loss: 0.0003
# Train Batch: 43200, Loss: 0.4815
# Train Batch: 43300, Loss: 0.0000
# Train Batch: 43400, Loss: 0.0513
# Train Batch: 43500, Loss: 0.0000
# Train Batch: 43600, Loss: 0.0002
# Train Batch: 43700, Loss: 1.7935
# Train Batch: 43800, Loss: 0.0000
# Train Batch: 43900, Loss: 0.0877
# Train Batch: 44000, Loss: 0.0000
# Train Batch: 44100, Loss: 1.4264
# Train Batch: 44200, Loss: 0.0457
# Train Batch: 44300, Loss: 5.9140
# Train Batch: 44400, Loss: 0.0001
# Train Batch: 44500, Loss: 0.1010
# Train Batch: 44600, Loss: 0.0007
# Train Batch: 44700, Loss: 0.0000
# Train Batch: 44800, Loss: 0.0000
# Train Batch: 44900, Loss: 0.0000
# Train Batch: 45000, Loss: 0.2661
# Train Batch: 45100, Loss: 0.0005
# Train Batch: 45200, Loss: 0.0000
# Train Batch: 45300, Loss: 0.0461
# Train Batch: 45400, Loss: 0.0000
# Train Batch: 45500, Loss: 0.0083
# Train Batch: 45600, Loss: 0.0001
# Train Batch: 45700, Loss: 0.3453
# Train Batch: 45800, Loss: 2.4079
# Train Batch: 45900, Loss: 0.0000
# Train Batch: 46000, Loss: 0.0052
# Train Batch: 46100, Loss: 0.0027
# Train Batch: 46200, Loss: 0.2096
# Train Batch: 46300, Loss: 1.7347
# Train Batch: 46400, Loss: 0.0000
# Train Batch: 46500, Loss: 0.0000
# Train Batch: 46600, Loss: 0.0000
# Train Batch: 46700, Loss: 0.0000
# Train Batch: 46800, Loss: 0.0068
# Train Batch: 46900, Loss: 0.0000
# Train Batch: 47000, Loss: 0.0000
# Train Batch: 47100, Loss: 0.1156
# Train Batch: 47200, Loss: 0.7065
# Train Batch: 47300, Loss: 0.0000
# Train Batch: 47400, Loss: 0.0000
# Train Batch: 47500, Loss: 0.0000
# Train Batch: 47600, Loss: 5.7298
# Train Batch: 47700, Loss: 0.0000
# Train Batch: 47800, Loss: 0.0000
# Train Batch: 47900, Loss: 0.0000
# Train Batch: 48000, Loss: 0.0002
# Train Batch: 48100, Loss: 0.0000
# Train Batch: 48200, Loss: 0.0064
# Train Batch: 48300, Loss: 0.0000
# Train Batch: 48400, Loss: 0.0156
# Train Batch: 48500, Loss: 0.3062
# Train Batch: 48600, Loss: 0.0000
# Train Batch: 48700, Loss: 0.0001
# Train Batch: 48800, Loss: 0.1495
# Train Batch: 48900, Loss: 0.0008
# Train Batch: 49000, Loss: 0.0000
# Train Batch: 49100, Loss: 0.0000
# Train Batch: 49200, Loss: 0.0051
# Train Batch: 49300, Loss: 1.4842
# Train Batch: 49400, Loss: 0.0089
# Train Batch: 49500, Loss: 0.0715
# Train Batch: 49600, Loss: 0.0874
# Train Batch: 49700, Loss: 0.0763
# Train Batch: 49800, Loss: 0.0000
# Train Batch: 49900, Loss: 0.0000
# Train Batch: 50000, Loss: 0.0000
# Train Batch: 50100, Loss: 0.0000
# Train Batch: 50200, Loss: 0.0000
# Train Batch: 50300, Loss: 0.0000
# Train Batch: 50400, Loss: 0.0001
# Train Batch: 50500, Loss: 0.5944
# Train Batch: 50600, Loss: 0.0000
# Train Batch: 50700, Loss: 0.0399
# Train Batch: 50800, Loss: 0.0000
# Train Batch: 50900, Loss: 0.0005
# Train Batch: 51000, Loss: 0.0006
# Train Batch: 51100, Loss: 0.0003
# Train Batch: 51200, Loss: 4.0010
# Train Batch: 51300, Loss: 0.9468
# Train Batch: 51400, Loss: 0.0000
# Train Batch: 51500, Loss: 0.0000
# Train Batch: 51600, Loss: 4.5932
# Train Batch: 51700, Loss: 0.0000
# Train Batch: 51800, Loss: 0.0000
# Train Batch: 51900, Loss: 0.0000
# Train Batch: 52000, Loss: 0.0015
# Train Batch: 52100, Loss: 0.2634
# Train Batch: 52200, Loss: 0.3436
# Train Batch: 52300, Loss: 0.0000
# Train Batch: 52400, Loss: 0.0000
# Train Batch: 52500, Loss: 5.0078
# Train Batch: 52600, Loss: 1.0632
# Train Batch: 52700, Loss: 0.0000
# Train Batch: 52800, Loss: 5.1565
# Train Batch: 52900, Loss: 0.0402
# Train Batch: 53000, Loss: 0.0000
# Train Batch: 53100, Loss: 0.0000
# Train Batch: 53200, Loss: 0.0000
# Train Batch: 53300, Loss: 0.0101
# Train Batch: 53400, Loss: 0.0006
# Train Batch: 53500, Loss: 0.0002
# Train Batch: 53600, Loss: 0.0120
# Train Batch: 53700, Loss: 0.3084
# Train Batch: 53800, Loss: 0.0000
# Train Batch: 53900, Loss: 0.0165
# Train Batch: 54000, Loss: 0.0169
# Train Batch: 54100, Loss: 0.0000
# Train Batch: 54200, Loss: 0.0000
# Train Batch: 54300, Loss: 0.0000
# Train Batch: 54400, Loss: 0.0047
# Train Batch: 54500, Loss: 0.0000
# Train Batch: 54600, Loss: 0.0000
# Train Batch: 54700, Loss: 0.0000
# Train Batch: 54800, Loss: 0.0000
# Train Batch: 54900, Loss: 0.0000
# Train Batch: 55000, Loss: 0.0000
# Train Batch: 55100, Loss: 0.0048
# Train Batch: 55200, Loss: 0.0000
# Train Batch: 55300, Loss: 0.0000
# Train Batch: 55400, Loss: 0.0000
# Train Batch: 55500, Loss: 0.0000
# Train Batch: 55600, Loss: 0.0000
# Train Batch: 55700, Loss: 0.0000
# Train Batch: 55800, Loss: 0.0002
# Train Batch: 55900, Loss: 0.0000
# Train Batch: 56000, Loss: 0.0000
# Train Batch: 56100, Loss: 0.0000
# Train Batch: 56200, Loss: 0.0000
# Train Batch: 56300, Loss: 0.9349
# Train Batch: 56400, Loss: 0.0000
# Train Batch: 56500, Loss: 0.2231
# Train Batch: 56600, Loss: 0.1721
# Train Batch: 56700, Loss: 0.0000
# Train Batch: 56800, Loss: 1.3939
# Train Batch: 56900, Loss: 0.0000
# Train Batch: 57000, Loss: 0.0000
# Train Batch: 57100, Loss: 0.0489
# Train Batch: 57200, Loss: 0.0000
# Train Batch: 57300, Loss: 0.0000
# Train Batch: 57400, Loss: 0.0006
# Train Batch: 57500, Loss: 0.0000
# Train Batch: 57600, Loss: 0.0000
# Train Batch: 57700, Loss: 0.0245
# Train Batch: 57800, Loss: 0.0025
# Train Batch: 57900, Loss: 0.0019
# Train Batch: 58000, Loss: 0.0000
# Train Batch: 58100, Loss: 0.0000
# Train Batch: 58200, Loss: 0.0000
# Train Batch: 58300, Loss: 0.0000
# Train Batch: 58400, Loss: 0.0000
# Train Batch: 58500, Loss: 0.0000
# Train Batch: 58600, Loss: 0.0000
# Train Batch: 58700, Loss: 0.0000
# Train Batch: 58800, Loss: 0.0000
# Train Batch: 58900, Loss: 0.0917
# Train Batch: 59000, Loss: 0.0000
# Train Batch: 59100, Loss: 0.0000
# Train Batch: 59200, Loss: 0.0000
# Train Batch: 59300, Loss: 0.0000
# Train Batch: 59400, Loss: 0.0043
# Train Batch: 59500, Loss: 0.0000
# Train Batch: 59600, Loss: 0.0000
# Train Batch: 59700, Loss: 0.0000
# Train Batch: 59800, Loss: 0.0002
# Train Batch: 59900, Loss: 0.0000
# Test Accuracy: 93.02%
# Epoch 2/5
# Train Batch: 0, Loss: 0.1580
# Train Batch: 100, Loss: 1.1478
# Train Batch: 200, Loss: 0.0225
# Train Batch: 300, Loss: 0.1733
# Train Batch: 400, Loss: 0.0000
# Train Batch: 500, Loss: 7.5666
# Train Batch: 600, Loss: 0.1706
# Train Batch: 700, Loss: 0.0028
# Train Batch: 800, Loss: 0.0038
# Train Batch: 900, Loss: 0.0723
# Train Batch: 1000, Loss: 0.0024
# Train Batch: 1100, Loss: 0.0101
# Train Batch: 1200, Loss: 0.0000
# Train Batch: 1300, Loss: 0.0000
# Train Batch: 1400, Loss: 0.0008
# Train Batch: 1500, Loss: 0.0033
# Train Batch: 1600, Loss: 0.1591
# Train Batch: 1700, Loss: 0.0000
# Train Batch: 1800, Loss: 0.0158
# Train Batch: 1900, Loss: 0.0000
# Train Batch: 2000, Loss: 2.4383
# Train Batch: 2100, Loss: 0.0000
# Train Batch: 2200, Loss: 0.0001
# Train Batch: 2300, Loss: 0.0000
# Train Batch: 2400, Loss: 0.0000
# Train Batch: 2500, Loss: 0.0000
# Train Batch: 2600, Loss: 3.2507
# Train Batch: 2700, Loss: 0.0000
# Train Batch: 2800, Loss: 0.0010
# Train Batch: 2900, Loss: 0.0000
# Train Batch: 3000, Loss: 0.1782
# Train Batch: 3100, Loss: 0.0010
# Train Batch: 3200, Loss: 0.0000
# Train Batch: 3300, Loss: 0.0000
# Train Batch: 3400, Loss: 0.0000
# Train Batch: 3500, Loss: 0.0001
# Train Batch: 3600, Loss: 0.0551
# Train Batch: 3700, Loss: 0.0007
# Train Batch: 3800, Loss: 0.0018
# Train Batch: 3900, Loss: 0.0000
# Train Batch: 4000, Loss: 0.0000
# Train Batch: 4100, Loss: 0.0023
# Train Batch: 4200, Loss: 0.0019
# Train Batch: 4300, Loss: 0.0000
# Train Batch: 4400, Loss: 0.0000
# Train Batch: 4500, Loss: 0.0000
# Train Batch: 4600, Loss: 0.3764
# Train Batch: 4700, Loss: 0.0566
# Train Batch: 4800, Loss: 0.0966
# Train Batch: 4900, Loss: 0.0144
# Train Batch: 5000, Loss: 0.1457
# Train Batch: 5100, Loss: 0.0000
# Train Batch: 5200, Loss: 0.0256
# Train Batch: 5300, Loss: 0.0000
# Train Batch: 5400, Loss: 0.0000
# Train Batch: 5500, Loss: 0.0000
# Train Batch: 5600, Loss: 14.5717
# Train Batch: 5700, Loss: 0.0004
# Train Batch: 5800, Loss: 0.0024
# Train Batch: 5900, Loss: 0.0000
# Train Batch: 6000, Loss: 0.0000
# Train Batch: 6100, Loss: 1.0180
# Train Batch: 6200, Loss: 0.0000
# Train Batch: 6300, Loss: 0.0031
# Train Batch: 6400, Loss: 0.0000
# Train Batch: 6500, Loss: 0.0891
# Train Batch: 6600, Loss: 0.0349
# Train Batch: 6700, Loss: 0.0000
# Train Batch: 6800, Loss: 0.0000
# Train Batch: 6900, Loss: 0.0000
# Train Batch: 7000, Loss: 0.0215
# Train Batch: 7100, Loss: 0.0001
# Train Batch: 7200, Loss: 0.0167
# Train Batch: 7300, Loss: 0.0164
# Train Batch: 7400, Loss: 0.0668
# Train Batch: 7500, Loss: 0.0000
# Train Batch: 7600, Loss: 0.0000
# Train Batch: 7700, Loss: 0.0541
# Train Batch: 7800, Loss: 0.0000
# Train Batch: 7900, Loss: 0.0210
# Train Batch: 8000, Loss: 0.0000
# Train Batch: 8100, Loss: 0.0000
# Train Batch: 8200, Loss: 3.2107
# Train Batch: 8300, Loss: 0.4430
# Train Batch: 8400, Loss: 0.0325
# Train Batch: 8500, Loss: 0.0000
# Train Batch: 8600, Loss: 0.1755
# Train Batch: 8700, Loss: 0.0095
# Train Batch: 8800, Loss: 0.0003
# Train Batch: 8900, Loss: 0.0000
# Train Batch: 9000, Loss: 0.0000
# Train Batch: 9100, Loss: 0.0000
# Train Batch: 9200, Loss: 0.0007
# Train Batch: 9300, Loss: 0.0000
# Train Batch: 9400, Loss: 0.0000
# Train Batch: 9500, Loss: 0.0000
# Train Batch: 9600, Loss: 0.0000
# Train Batch: 9700, Loss: 0.0000
# Train Batch: 9800, Loss: 0.0005
# Train Batch: 9900, Loss: 0.0006
# Train Batch: 10000, Loss: 0.0000
# Train Batch: 10100, Loss: 0.0569
# Train Batch: 10200, Loss: 0.0000
# Train Batch: 10300, Loss: 0.0582
# Train Batch: 10400, Loss: 0.7383
# Train Batch: 10500, Loss: 0.0000
# Train Batch: 10600, Loss: 0.0000
# Train Batch: 10700, Loss: 0.0019
# Train Batch: 10800, Loss: 2.1723
# Train Batch: 10900, Loss: 0.0000
# Train Batch: 11000, Loss: 0.0000
# Train Batch: 11100, Loss: 1.1579
# Train Batch: 11200, Loss: 0.0000
# Train Batch: 11300, Loss: 0.0000
# Train Batch: 11400, Loss: 0.0378
# Train Batch: 11500, Loss: 0.0000
# Train Batch: 11600, Loss: 1.1165
# Train Batch: 11700, Loss: 0.0023
# Train Batch: 11800, Loss: 0.0000
# Train Batch: 11900, Loss: 0.2465
# Train Batch: 12000, Loss: 1.5464
# Train Batch: 12100, Loss: 0.0000
# Train Batch: 12200, Loss: 0.0136
# Train Batch: 12300, Loss: 0.0000
# Train Batch: 12400, Loss: 0.0002
# Train Batch: 12500, Loss: 0.0000
# Train Batch: 12600, Loss: 0.0026
# Train Batch: 12700, Loss: 0.0000
# Train Batch: 12800, Loss: 0.0000
# Train Batch: 12900, Loss: 5.5627
# Train Batch: 13000, Loss: 0.0000
# Train Batch: 13100, Loss: 0.0041
# Train Batch: 13200, Loss: 0.0661
# Train Batch: 13300, Loss: 0.0000
# Train Batch: 13400, Loss: 2.2660
# Train Batch: 13500, Loss: 0.0000
# Train Batch: 13600, Loss: 0.0000
# Train Batch: 13700, Loss: 0.0000
# Train Batch: 13800, Loss: 0.0006
# Train Batch: 13900, Loss: 0.0030
# Train Batch: 14000, Loss: 0.0000
# Train Batch: 14100, Loss: 2.2376
# Train Batch: 14200, Loss: 0.0000
# Train Batch: 14300, Loss: 0.0000
# Train Batch: 14400, Loss: 0.0000
# Train Batch: 14500, Loss: 1.9608
# Train Batch: 14600, Loss: 0.0000
# Train Batch: 14700, Loss: 0.0745
# Train Batch: 14800, Loss: 0.1569
# Train Batch: 14900, Loss: 0.0014
# Train Batch: 15000, Loss: 0.0000
# Train Batch: 15100, Loss: 0.0001
# Train Batch: 15200, Loss: 0.0000
# Train Batch: 15300, Loss: 0.0000
# Train Batch: 15400, Loss: 0.0136
# Train Batch: 15500, Loss: 0.4899
# Train Batch: 15600, Loss: 0.0000
# Train Batch: 15700, Loss: 0.0000
# Train Batch: 15800, Loss: 0.0000
# Train Batch: 15900, Loss: 0.0000
# Train Batch: 16000, Loss: 0.0000
# Train Batch: 16100, Loss: 0.9135
# Train Batch: 16200, Loss: 0.0001
# Train Batch: 16300, Loss: 0.0000
# Train Batch: 16400, Loss: 0.0000
# Train Batch: 16500, Loss: 0.0001
# Train Batch: 16600, Loss: 0.0178
# Train Batch: 16700, Loss: 0.0715
# Train Batch: 16800, Loss: 0.0000
# Train Batch: 16900, Loss: 0.0000
# Train Batch: 17000, Loss: 0.0000
# Train Batch: 17100, Loss: 0.0012
# Train Batch: 17200, Loss: 1.6276
# Train Batch: 17300, Loss: 0.0072
# Train Batch: 17400, Loss: 0.0001
# Train Batch: 17500, Loss: 0.0290
# Train Batch: 17600, Loss: 0.0007
# Train Batch: 17700, Loss: 4.6561
# Train Batch: 17800, Loss: 0.0273
# Train Batch: 17900, Loss: 0.0000
# Train Batch: 18000, Loss: 0.0009
# Train Batch: 18100, Loss: 0.0000
# Train Batch: 18200, Loss: 0.0000
# Train Batch: 18300, Loss: 0.0000
# Train Batch: 18400, Loss: 0.0000
# Train Batch: 18500, Loss: 0.0125
# Train Batch: 18600, Loss: 0.0007
# Train Batch: 18700, Loss: 0.0827
# Train Batch: 18800, Loss: 0.0000
# Train Batch: 18900, Loss: 21.9125
# Train Batch: 19000, Loss: 0.0001
# Train Batch: 19100, Loss: 0.0000
# Train Batch: 19200, Loss: 0.0014
# Train Batch: 19300, Loss: 0.0000
# Train Batch: 19400, Loss: 0.0000
# Train Batch: 19500, Loss: 0.0000
# Train Batch: 19600, Loss: 0.0023
# Train Batch: 19700, Loss: 0.0000
# Train Batch: 19800, Loss: 0.0000
# Train Batch: 19900, Loss: 0.0000
# Train Batch: 20000, Loss: 0.0010
# Train Batch: 20100, Loss: 0.0076
# Train Batch: 20200, Loss: 0.0000
# Train Batch: 20300, Loss: 0.0003
# Train Batch: 20400, Loss: 0.0000
# Train Batch: 20500, Loss: 0.0002
# Train Batch: 20600, Loss: 0.1196
# Train Batch: 20700, Loss: 0.0000
# Train Batch: 20800, Loss: 0.0000
# Train Batch: 20900, Loss: 0.2459
# Train Batch: 21000, Loss: 0.7795
# Train Batch: 21100, Loss: 0.0002
# Train Batch: 21200, Loss: 0.0000
# Train Batch: 21300, Loss: 0.0049
# Train Batch: 21400, Loss: 0.0000
# Train Batch: 21500, Loss: 0.0159
# Train Batch: 21600, Loss: 0.0000
# Train Batch: 21700, Loss: 2.9085
# Train Batch: 21800, Loss: 0.0001
# Train Batch: 21900, Loss: 0.0000
# Train Batch: 22000, Loss: 0.0000
# Train Batch: 22100, Loss: 0.0457
# Train Batch: 22200, Loss: 1.6618
# Train Batch: 22300, Loss: 0.0000
# Train Batch: 22400, Loss: 1.5786
# Train Batch: 22500, Loss: 0.0000
# Train Batch: 22600, Loss: 0.0039
# Train Batch: 22700, Loss: 0.0000
# Train Batch: 22800, Loss: 0.0890
# Train Batch: 22900, Loss: 0.0000
# Train Batch: 23000, Loss: 0.0000
# Train Batch: 23100, Loss: 2.9403
# Train Batch: 23200, Loss: 0.0000
# Train Batch: 23300, Loss: 0.0052
# Train Batch: 23400, Loss: 1.3264
# Train Batch: 23500, Loss: 0.0000
# Train Batch: 23600, Loss: 0.0093
# Train Batch: 23700, Loss: 0.0000
# Train Batch: 23800, Loss: 0.0004
# Train Batch: 23900, Loss: 0.0000
# Train Batch: 24000, Loss: 0.0004
# Train Batch: 24100, Loss: 0.0000
# Train Batch: 24200, Loss: 0.0000
# Train Batch: 24300, Loss: 2.0729
# Train Batch: 24400, Loss: 0.0000
# Train Batch: 24500, Loss: 0.0000
# Train Batch: 24600, Loss: 0.0000
# Train Batch: 24700, Loss: 0.0000
# Train Batch: 24800, Loss: 0.0000
# Train Batch: 24900, Loss: 0.0000
# Train Batch: 25000, Loss: 0.0406
# Train Batch: 25100, Loss: 0.0341
# Train Batch: 25200, Loss: 0.0000
# Train Batch: 25300, Loss: 3.2749
# Train Batch: 25400, Loss: 0.0868
# Train Batch: 25500, Loss: 0.0000
# Train Batch: 25600, Loss: 0.0000
# Train Batch: 25700, Loss: 0.0000
# Train Batch: 25800, Loss: 4.3384
# Train Batch: 25900, Loss: 0.4122
# Train Batch: 26000, Loss: 0.0003
# Train Batch: 26100, Loss: 0.0023
# Train Batch: 26200, Loss: 0.0000
# Train Batch: 26300, Loss: 2.8166
# Train Batch: 26400, Loss: 0.0000
# Train Batch: 26500, Loss: 0.0002
# Train Batch: 26600, Loss: 5.7630
# Train Batch: 26700, Loss: 0.0289
# Train Batch: 26800, Loss: 0.0000
# Train Batch: 26900, Loss: 6.1449
# Train Batch: 27000, Loss: 0.0785
# Train Batch: 27100, Loss: 0.0022
# Train Batch: 27200, Loss: 0.0525
# Train Batch: 27300, Loss: 0.0000
# Train Batch: 27400, Loss: 0.0000
# Train Batch: 27500, Loss: 0.0000
# Train Batch: 27600, Loss: 0.0130
# Train Batch: 27700, Loss: 0.0035
# Train Batch: 27800, Loss: 0.0000
# Train Batch: 27900, Loss: 0.0344
# Train Batch: 28000, Loss: 0.0000
# Train Batch: 28100, Loss: 0.0000
# Train Batch: 28200, Loss: 0.0244
# Train Batch: 28300, Loss: 0.0000
# Train Batch: 28400, Loss: 0.0000
# Train Batch: 28500, Loss: 0.0000
# Train Batch: 28600, Loss: 0.0037
# Train Batch: 28700, Loss: 0.0008
# Train Batch: 28800, Loss: 0.0000
# Train Batch: 28900, Loss: 0.0000
# Train Batch: 29000, Loss: 0.0263
# Train Batch: 29100, Loss: 0.0019
# Train Batch: 29200, Loss: 0.0208
# Train Batch: 29300, Loss: 0.0003
# Train Batch: 29400, Loss: 0.0000
# Train Batch: 29500, Loss: 0.0001
# Train Batch: 29600, Loss: 0.0000
# Train Batch: 29700, Loss: 0.5573
# Train Batch: 29800, Loss: 0.0000
# Train Batch: 29900, Loss: 0.0473
# Train Batch: 30000, Loss: 0.0000
# Train Batch: 30100, Loss: 0.0049
# Train Batch: 30200, Loss: 0.0000
# Train Batch: 30300, Loss: 0.0005
# Train Batch: 30400, Loss: 0.0000
# Train Batch: 30500, Loss: 0.0002
# Train Batch: 30600, Loss: 0.0278
# Train Batch: 30700, Loss: 0.0027
# Train Batch: 30800, Loss: 0.0000
# Train Batch: 30900, Loss: 5.4464
# Train Batch: 31000, Loss: 10.1211
# Train Batch: 31100, Loss: 3.4653
# Train Batch: 31200, Loss: 0.0328
# Train Batch: 31300, Loss: 0.0100
# Train Batch: 31400, Loss: 0.0000
# Train Batch: 31500, Loss: 0.8961
# Train Batch: 31600, Loss: 7.0566
# Train Batch: 31700, Loss: 0.0041
# Train Batch: 31800, Loss: 0.1775
# Train Batch: 31900, Loss: 0.0000
# Train Batch: 32000, Loss: 0.0006
# Train Batch: 32100, Loss: 0.0859
# Train Batch: 32200, Loss: 0.0000
# Train Batch: 32300, Loss: 0.0016
# Train Batch: 32400, Loss: 0.0024
# Train Batch: 32500, Loss: 0.0000
# Train Batch: 32600, Loss: 0.0000
# Train Batch: 32700, Loss: 0.0036
# Train Batch: 32800, Loss: 0.0000
# Train Batch: 32900, Loss: 0.0000
# Train Batch: 33000, Loss: 2.3151
# Train Batch: 33100, Loss: 0.0000
# Train Batch: 33200, Loss: 0.6403
# Train Batch: 33300, Loss: 0.0001
# Train Batch: 33400, Loss: 0.0001
# Train Batch: 33500, Loss: 0.0000
# Train Batch: 33600, Loss: 0.0000
# Train Batch: 33700, Loss: 0.0001
# Train Batch: 33800, Loss: 0.0000
# Train Batch: 33900, Loss: 0.0000
# Train Batch: 34000, Loss: 0.0003
# Train Batch: 34100, Loss: 0.8641
# Train Batch: 34200, Loss: 0.0000
# Train Batch: 34300, Loss: 1.3318
# Train Batch: 34400, Loss: 0.0000
# Train Batch: 34500, Loss: 8.9133
# Train Batch: 34600, Loss: 0.0007
# Train Batch: 34700, Loss: 0.2935
# Train Batch: 34800, Loss: 1.8503
# Train Batch: 34900, Loss: 0.0001
# Train Batch: 35000, Loss: 0.0000
# Train Batch: 35100, Loss: 0.0034
# Train Batch: 35200, Loss: 0.0000
# Train Batch: 35300, Loss: 0.0921
# Train Batch: 35400, Loss: 0.0000
# Train Batch: 35500, Loss: 0.0001
# Train Batch: 35600, Loss: 0.0000
# Train Batch: 35700, Loss: 0.0000
# Train Batch: 35800, Loss: 0.0000
# Train Batch: 35900, Loss: 0.0000
# Train Batch: 36000, Loss: 0.0367
# Train Batch: 36100, Loss: 0.0008
# Train Batch: 36200, Loss: 0.0001
# Train Batch: 36300, Loss: 0.0329
# Train Batch: 36400, Loss: 0.0000
# Train Batch: 36500, Loss: 0.0279
# Train Batch: 36600, Loss: 0.0002
# Train Batch: 36700, Loss: 0.0660
# Train Batch: 36800, Loss: 0.0001
# Train Batch: 36900, Loss: 2.0162
# Train Batch: 37000, Loss: 0.0000
# Train Batch: 37100, Loss: 0.5859
# Train Batch: 37200, Loss: 0.0000
# Train Batch: 37300, Loss: 0.0000
# Train Batch: 37400, Loss: 0.6269
# Train Batch: 37500, Loss: 0.0000
# Train Batch: 37600, Loss: 0.0001
# Train Batch: 37700, Loss: 0.0000
# Train Batch: 37800, Loss: 0.0000
# Train Batch: 37900, Loss: 0.0000
# Train Batch: 38000, Loss: 0.0287
# Train Batch: 38100, Loss: 0.0000
# Train Batch: 38200, Loss: 0.0000
# Train Batch: 38300, Loss: 0.0000
# Train Batch: 38400, Loss: 0.0000
# Train Batch: 38500, Loss: 0.0000
# Train Batch: 38600, Loss: 0.0004
# Train Batch: 38700, Loss: 4.3167
# Train Batch: 38800, Loss: 0.2947
# Train Batch: 38900, Loss: 0.0000
# Train Batch: 39000, Loss: 0.0461
# Train Batch: 39100, Loss: 0.0000
# Train Batch: 39200, Loss: 0.0000
# Train Batch: 39300, Loss: 0.0000
# Train Batch: 39400, Loss: 0.0000
# Train Batch: 39500, Loss: 0.0670
# Train Batch: 39600, Loss: 2.1696
# Train Batch: 39700, Loss: 0.0000
# Train Batch: 39800, Loss: 0.0000
# Train Batch: 39900, Loss: 0.0000
# Train Batch: 40000, Loss: 0.0000
# Train Batch: 40100, Loss: 0.1719
# Train Batch: 40200, Loss: 0.0000
# Train Batch: 40300, Loss: 0.5121
# Train Batch: 40400, Loss: 0.0000
# Train Batch: 40500, Loss: 0.0000
# Train Batch: 40600, Loss: 0.0000
# Train Batch: 40700, Loss: 0.0111
# Train Batch: 40800, Loss: 0.0011
# Train Batch: 40900, Loss: 0.0002
# Train Batch: 41000, Loss: 0.0000
# Train Batch: 41100, Loss: 0.0000
# Train Batch: 41200, Loss: 0.0002
# Train Batch: 41300, Loss: 0.0003
# Train Batch: 41400, Loss: 0.9452
# Train Batch: 41500, Loss: 0.0012
# Train Batch: 41600, Loss: 0.0000
# Train Batch: 41700, Loss: 0.9823
# Train Batch: 41800, Loss: 0.0000
# Train Batch: 41900, Loss: 0.0000
# Train Batch: 42000, Loss: 0.0000
# Train Batch: 42100, Loss: 0.0000
# Train Batch: 42200, Loss: 0.0000
# Train Batch: 42300, Loss: 0.0000
# Train Batch: 42400, Loss: 0.0003
# Train Batch: 42500, Loss: 0.0000
# Train Batch: 42600, Loss: 0.0000
# Train Batch: 42700, Loss: 0.0000
# Train Batch: 42800, Loss: 0.0000
# Train Batch: 42900, Loss: 0.0093
# Train Batch: 43000, Loss: 0.0240
# Train Batch: 43100, Loss: 0.0000
# Train Batch: 43200, Loss: 0.0081
# Train Batch: 43300, Loss: 0.0000
# Train Batch: 43400, Loss: 0.0038
# Train Batch: 43500, Loss: 0.0000
# Train Batch: 43600, Loss: 0.0157
# Train Batch: 43700, Loss: 0.0583
# Train Batch: 43800, Loss: 0.4506
# Train Batch: 43900, Loss: 0.0684
# Train Batch: 44000, Loss: 0.0000
# Train Batch: 44100, Loss: 0.6824
# Train Batch: 44200, Loss: 0.0543
# Train Batch: 44300, Loss: 0.0000
# Train Batch: 44400, Loss: 0.0000
# Train Batch: 44500, Loss: 0.0049
# Train Batch: 44600, Loss: 0.0001
# Train Batch: 44700, Loss: 0.0000
# Train Batch: 44800, Loss: 0.0000
# Train Batch: 44900, Loss: 0.0000
# Train Batch: 45000, Loss: 0.0000
# Train Batch: 45100, Loss: 0.0000
# Train Batch: 45200, Loss: 0.0000
# Train Batch: 45300, Loss: 0.0000
# Train Batch: 45400, Loss: 0.0000
# Train Batch: 45500, Loss: 0.0003
# Train Batch: 45600, Loss: 0.0000
# Train Batch: 45700, Loss: 0.0441
# Train Batch: 45800, Loss: 0.0078
# Train Batch: 45900, Loss: 0.0000
# Train Batch: 46000, Loss: 0.0006
# Train Batch: 46100, Loss: 0.0002
# Train Batch: 46200, Loss: 0.0002
# Train Batch: 46300, Loss: 0.0000
# Train Batch: 46400, Loss: 0.0000
# Train Batch: 46500, Loss: 0.0000
# Train Batch: 46600, Loss: 0.0000
# Train Batch: 46700, Loss: 0.0000
# Train Batch: 46800, Loss: 0.0009
# Train Batch: 46900, Loss: 0.0000
# Train Batch: 47000, Loss: 0.0000
# Train Batch: 47100, Loss: 0.6010
# Train Batch: 47200, Loss: 1.0800
# Train Batch: 47300, Loss: 0.0000
# Train Batch: 47400, Loss: 0.0000
# Train Batch: 47500, Loss: 0.0000
# Train Batch: 47600, Loss: 8.0724
# Train Batch: 47700, Loss: 0.0000
# Train Batch: 47800, Loss: 0.0000
# Train Batch: 47900, Loss: 0.0000
# Train Batch: 48000, Loss: 0.0589
# Train Batch: 48100, Loss: 0.0000
# Train Batch: 48200, Loss: 0.0177
# Train Batch: 48300, Loss: 0.0000
# Train Batch: 48400, Loss: 0.0000
# Train Batch: 48500, Loss: 0.3280
# Train Batch: 48600, Loss: 0.0000
# Train Batch: 48700, Loss: 0.0004
# Train Batch: 48800, Loss: 0.7515
# Train Batch: 48900, Loss: 0.0627
# Train Batch: 49000, Loss: 0.0000
# Train Batch: 49100, Loss: 0.0000
# Train Batch: 49200, Loss: 0.4484
# Train Batch: 49300, Loss: 1.1218
# Train Batch: 49400, Loss: 0.0162
# Train Batch: 49500, Loss: 0.0000
# Train Batch: 49600, Loss: 0.0180
# Train Batch: 49700, Loss: 0.0030
# Train Batch: 49800, Loss: 0.0000
# Train Batch: 49900, Loss: 0.0000
# Train Batch: 50000, Loss: 0.0000
# Train Batch: 50100, Loss: 0.0000
# Train Batch: 50200, Loss: 0.0000
# Train Batch: 50300, Loss: 0.0000
# Train Batch: 50400, Loss: 0.0000
# Train Batch: 50500, Loss: 0.4076
# Train Batch: 50600, Loss: 0.0000
# Train Batch: 50700, Loss: 1.5850
# Train Batch: 50800, Loss: 0.0000
# Train Batch: 50900, Loss: 0.0217
# Train Batch: 51000, Loss: 0.0008
# Train Batch: 51100, Loss: 0.0174
# Train Batch: 51200, Loss: 0.7771
# Train Batch: 51300, Loss: 0.0410
# Train Batch: 51400, Loss: 0.5761
# Train Batch: 51500, Loss: 0.0001
# Train Batch: 51600, Loss: 1.7707
# Train Batch: 51700, Loss: 0.0000
# Train Batch: 51800, Loss: 0.0000
# Train Batch: 51900, Loss: 0.0000
# Train Batch: 52000, Loss: 0.0062
# Train Batch: 52100, Loss: 1.6540
# Train Batch: 52200, Loss: 0.2636
# Train Batch: 52300, Loss: 0.0000
# Train Batch: 52400, Loss: 0.0000
# Train Batch: 52500, Loss: 0.0009
# Train Batch: 52600, Loss: 0.0309
# Train Batch: 52700, Loss: 0.0000
# Train Batch: 52800, Loss: 3.7073
# Train Batch: 52900, Loss: 0.0659
# Train Batch: 53000, Loss: 0.0000
# Train Batch: 53100, Loss: 0.0000
# Train Batch: 53200, Loss: 0.0000
# Train Batch: 53300, Loss: 0.0600
# Train Batch: 53400, Loss: 0.0378
# Train Batch: 53500, Loss: 0.0033
# Train Batch: 53600, Loss: 0.0187
# Train Batch: 53700, Loss: 1.4380
# Train Batch: 53800, Loss: 0.0000
# Train Batch: 53900, Loss: 0.0006
# Train Batch: 54000, Loss: 0.0000
# Train Batch: 54100, Loss: 0.0000
# Train Batch: 54200, Loss: 0.0000
# Train Batch: 54300, Loss: 0.0000
# Train Batch: 54400, Loss: 0.0000
# Train Batch: 54500, Loss: 0.0000
# Train Batch: 54600, Loss: 0.0000
# Train Batch: 54700, Loss: 0.0000
# Train Batch: 54800, Loss: 0.0000
# Train Batch: 54900, Loss: 0.0000
# Train Batch: 55000, Loss: 0.0000
# Train Batch: 55100, Loss: 0.0293
# Train Batch: 55200, Loss: 0.0000
# Train Batch: 55300, Loss: 0.0000
# Train Batch: 55400, Loss: 0.0000
# Train Batch: 55500, Loss: 0.0000
# Train Batch: 55600, Loss: 0.0000
# Train Batch: 55700, Loss: 0.0000
# Train Batch: 55800, Loss: 0.0000
# Train Batch: 55900, Loss: 0.0000
# Train Batch: 56000, Loss: 0.0000
# Train Batch: 56100, Loss: 0.0000
# Train Batch: 56200, Loss: 0.0000
# Train Batch: 56300, Loss: 2.1750
# Train Batch: 56400, Loss: 0.0000
# Train Batch: 56500, Loss: 0.0000
# Train Batch: 56600, Loss: 0.0067
# Train Batch: 56700, Loss: 0.0000
# Train Batch: 56800, Loss: 1.2368
# Train Batch: 56900, Loss: 0.0000
# Train Batch: 57000, Loss: 0.0000
# Train Batch: 57100, Loss: 0.5931
# Train Batch: 57200, Loss: 0.0000
# Train Batch: 57300, Loss: 0.0344
# Train Batch: 57400, Loss: 0.0000
# Train Batch: 57500, Loss: 0.0000
# Train Batch: 57600, Loss: 0.0008
# Train Batch: 57700, Loss: 0.0912
# Train Batch: 57800, Loss: 0.0000
# Train Batch: 57900, Loss: 0.0000
# Train Batch: 58000, Loss: 0.0000
# Train Batch: 58100, Loss: 0.0000
# Train Batch: 58200, Loss: 0.0000
# Train Batch: 58300, Loss: 0.0001
# Train Batch: 58400, Loss: 0.0000
# Train Batch: 58500, Loss: 0.0000
# Train Batch: 58600, Loss: 0.0000
# Train Batch: 58700, Loss: 0.0000
# Train Batch: 58800, Loss: 0.0000
# Train Batch: 58900, Loss: 0.0006
# Train Batch: 59000, Loss: 0.0000
# Train Batch: 59100, Loss: 0.0000
# Train Batch: 59200, Loss: 0.0000
# Train Batch: 59300, Loss: 0.0000
# Train Batch: 59400, Loss: 0.0000
# Train Batch: 59500, Loss: 0.0000
# Train Batch: 59600, Loss: 0.0000
# Train Batch: 59700, Loss: 0.0000
# Train Batch: 59800, Loss: 0.0000
# Train Batch: 59900, Loss: 0.0000
# Test Accuracy: 93.24%
# Epoch 3/5
# Train Batch: 0, Loss: 0.0000
# Train Batch: 100, Loss: 1.1034
# Train Batch: 200, Loss: 0.0000
# Train Batch: 300, Loss: 0.0233
# Train Batch: 400, Loss: 0.0000
# Train Batch: 500, Loss: 4.0958
# Train Batch: 600, Loss: 0.0045
# Train Batch: 700, Loss: 0.0026
# Train Batch: 800, Loss: 0.0002
# Train Batch: 900, Loss: 0.3808
# Train Batch: 1000, Loss: 0.0003
# Train Batch: 1100, Loss: 0.0608
# Train Batch: 1200, Loss: 0.0000
# Train Batch: 1300, Loss: 0.0000
# Train Batch: 1400, Loss: 0.0001
# Train Batch: 1500, Loss: 0.0158
# Train Batch: 1600, Loss: 0.1205
# Train Batch: 1700, Loss: 0.0000
# Train Batch: 1800, Loss: 0.0009
# Train Batch: 1900, Loss: 0.0000
# Train Batch: 2000, Loss: 1.4038
# Train Batch: 2100, Loss: 0.0000
# Train Batch: 2200, Loss: 0.0318
# Train Batch: 2300, Loss: 0.0000
# Train Batch: 2400, Loss: 0.0000
# Train Batch: 2500, Loss: 0.0000
# Train Batch: 2600, Loss: 1.6097
# Train Batch: 2700, Loss: 0.0000
# Train Batch: 2800, Loss: 0.0000
# Train Batch: 2900, Loss: 0.0000
# Train Batch: 3000, Loss: 0.0008
# Train Batch: 3100, Loss: 0.0000
# Train Batch: 3200, Loss: 0.0000
# Train Batch: 3300, Loss: 0.0004
# Train Batch: 3400, Loss: 0.0000
# Train Batch: 3500, Loss: 0.0000
# Train Batch: 3600, Loss: 0.1219
# Train Batch: 3700, Loss: 0.0000
# Train Batch: 3800, Loss: 0.0000
# Train Batch: 3900, Loss: 0.0000
# Train Batch: 4000, Loss: 0.0000
# Train Batch: 4100, Loss: 0.0000
# Train Batch: 4200, Loss: 0.0253
# Train Batch: 4300, Loss: 0.0000
# Train Batch: 4400, Loss: 0.0000
# Train Batch: 4500, Loss: 0.0000
# Train Batch: 4600, Loss: 0.0138
# Train Batch: 4700, Loss: 0.0115
# Train Batch: 4800, Loss: 0.0611
# Train Batch: 4900, Loss: 0.0000
# Train Batch: 5000, Loss: 0.2230
# Train Batch: 5100, Loss: 0.0005
# Train Batch: 5200, Loss: 0.0085
# Train Batch: 5300, Loss: 0.0000
# Train Batch: 5400, Loss: 0.0000
# Train Batch: 5500, Loss: 0.0000
# Train Batch: 5600, Loss: 0.0000
# Train Batch: 5700, Loss: 0.0001
# Train Batch: 5800, Loss: 0.0000
# Train Batch: 5900, Loss: 0.0000
# Train Batch: 6000, Loss: 0.0000
# Train Batch: 6100, Loss: 0.5675
# Train Batch: 6200, Loss: 0.0000
# Train Batch: 6300, Loss: 0.0007
# Train Batch: 6400, Loss: 0.0000
# Train Batch: 6500, Loss: 0.0000
# Train Batch: 6600, Loss: 1.4511
# Train Batch: 6700, Loss: 0.0000
# Train Batch: 6800, Loss: 0.0028
# Train Batch: 6900, Loss: 0.0000
# Train Batch: 7000, Loss: 0.0144
# Train Batch: 7100, Loss: 0.0000
# Train Batch: 7200, Loss: 0.0194
# Train Batch: 7300, Loss: 0.0350
# Train Batch: 7400, Loss: 0.0084
# Train Batch: 7500, Loss: 0.0003
# Train Batch: 7600, Loss: 0.0000
# Train Batch: 7700, Loss: 0.0048
# Train Batch: 7800, Loss: 0.0000
# Train Batch: 7900, Loss: 0.0027
# Train Batch: 8000, Loss: 0.0000
# Train Batch: 8100, Loss: 0.0000
# Train Batch: 8200, Loss: 11.0095
# Train Batch: 8300, Loss: 0.0214
# Train Batch: 8400, Loss: 0.4480
# Train Batch: 8500, Loss: 0.0000
# Train Batch: 8600, Loss: 0.1147
# Train Batch: 8700, Loss: 0.0000
# Train Batch: 8800, Loss: 0.0000
# Train Batch: 8900, Loss: 0.0000
# Train Batch: 9000, Loss: 0.0000
# Train Batch: 9100, Loss: 0.0000
# Train Batch: 9200, Loss: 0.0008
# Train Batch: 9300, Loss: 0.0000
# Train Batch: 9400, Loss: 0.0000
# Train Batch: 9500, Loss: 0.0029
# Train Batch: 9600, Loss: 0.0000
# Train Batch: 9700, Loss: 0.0000
# Train Batch: 9800, Loss: 0.0000
# Train Batch: 9900, Loss: 0.0001
# Train Batch: 10000, Loss: 0.0000
# Train Batch: 10100, Loss: 0.0298
# Train Batch: 10200, Loss: 0.0015
# Train Batch: 10300, Loss: 0.0082
# Train Batch: 10400, Loss: 0.0010
# Train Batch: 10500, Loss: 0.0000
# Train Batch: 10600, Loss: 0.0025
# Train Batch: 10700, Loss: 0.0249
# Train Batch: 10800, Loss: 0.0206
# Train Batch: 10900, Loss: 0.0000
# Train Batch: 11000, Loss: 0.0000
# Train Batch: 11100, Loss: 0.2782
# Train Batch: 11200, Loss: 0.0000
# Train Batch: 11300, Loss: 0.0000
# Train Batch: 11400, Loss: 0.0085
# Train Batch: 11500, Loss: 0.0002
# Train Batch: 11600, Loss: 1.5166
# Train Batch: 11700, Loss: 0.0084
# Train Batch: 11800, Loss: 0.0000
# Train Batch: 11900, Loss: 0.0642
# Train Batch: 12000, Loss: 1.5080
# Train Batch: 12100, Loss: 0.0000
# Train Batch: 12200, Loss: 0.0003
# Train Batch: 12300, Loss: 0.0000
# Train Batch: 12400, Loss: 0.0001
# Train Batch: 12500, Loss: 0.0000
# Train Batch: 12600, Loss: 0.0024
# Train Batch: 12700, Loss: 0.0000
# Train Batch: 12800, Loss: 0.0000
# Train Batch: 12900, Loss: 0.1336
# Train Batch: 13000, Loss: 0.0033
# Train Batch: 13100, Loss: 0.0719
# Train Batch: 13200, Loss: 0.0253
# Train Batch: 13300, Loss: 0.0000
# Train Batch: 13400, Loss: 0.0051
# Train Batch: 13500, Loss: 0.0012
# Train Batch: 13600, Loss: 0.0000
# Train Batch: 13700, Loss: 0.0000
# Train Batch: 13800, Loss: 0.0005
# Train Batch: 13900, Loss: 0.0144
# Train Batch: 14000, Loss: 0.0000
# Train Batch: 14100, Loss: 1.8102
# Train Batch: 14200, Loss: 0.0000
# Train Batch: 14300, Loss: 0.0000
# Train Batch: 14400, Loss: 0.0000
# Train Batch: 14500, Loss: 2.5539
# Train Batch: 14600, Loss: 0.0000
# Train Batch: 14700, Loss: 1.3037
# Train Batch: 14800, Loss: 0.0085
# Train Batch: 14900, Loss: 0.0000
# Train Batch: 15000, Loss: 0.0000
# Train Batch: 15100, Loss: 0.0001
# Train Batch: 15200, Loss: 0.0000
# Train Batch: 15300, Loss: 0.0000
# Train Batch: 15400, Loss: 0.0491
# Train Batch: 15500, Loss: 0.0697
# Train Batch: 15600, Loss: 0.0000
# Train Batch: 15700, Loss: 0.0000
# Train Batch: 15800, Loss: 0.0000
# Train Batch: 15900, Loss: 0.0000
# Train Batch: 16000, Loss: 0.0000
# Train Batch: 16100, Loss: 1.4689
# Train Batch: 16200, Loss: 0.0000
# Train Batch: 16300, Loss: 0.0000
# Train Batch: 16400, Loss: 0.0000
# Train Batch: 16500, Loss: 0.0000
# Train Batch: 16600, Loss: 0.0339
# Train Batch: 16700, Loss: 0.0009
# Train Batch: 16800, Loss: 0.0000
# Train Batch: 16900, Loss: 0.0000
# Train Batch: 17000, Loss: 0.0000
# Train Batch: 17100, Loss: 0.0000
# Train Batch: 17200, Loss: 0.0131
# Train Batch: 17300, Loss: 0.0020
# Train Batch: 17400, Loss: 0.0176
# Train Batch: 17500, Loss: 0.0217
# Train Batch: 17600, Loss: 0.0000
# Train Batch: 17700, Loss: 0.0000
# Train Batch: 17800, Loss: 0.0001
# Train Batch: 17900, Loss: 0.0035
# Train Batch: 18000, Loss: 0.0006
# Train Batch: 18100, Loss: 0.0006
# Train Batch: 18200, Loss: 0.0000
# Train Batch: 18300, Loss: 0.0000
# Train Batch: 18400, Loss: 0.0000
# Train Batch: 18500, Loss: 0.0174
# Train Batch: 18600, Loss: 0.0001
# Train Batch: 18700, Loss: 0.0063
# Train Batch: 18800, Loss: 0.0000
# Train Batch: 18900, Loss: 1.4151
# Train Batch: 19000, Loss: 0.0102
# Train Batch: 19100, Loss: 0.0000
# Train Batch: 19200, Loss: 0.0006
# Train Batch: 19300, Loss: 0.0000
# Train Batch: 19400, Loss: 0.0000
# Train Batch: 19500, Loss: 0.0000
# Train Batch: 19600, Loss: 0.0453
# Train Batch: 19700, Loss: 0.0046
# Train Batch: 19800, Loss: 0.0000
# Train Batch: 19900, Loss: 0.0000
# Train Batch: 20000, Loss: 0.0000
# Train Batch: 20100, Loss: 0.0433
# Train Batch: 20200, Loss: 0.0000
# Train Batch: 20300, Loss: 0.0021
# Train Batch: 20400, Loss: 0.0000
# Train Batch: 20500, Loss: 0.0002
# Train Batch: 20600, Loss: 0.0173
# Train Batch: 20700, Loss: 0.0000
# Train Batch: 20800, Loss: 0.0000
# Train Batch: 20900, Loss: 0.0029
# Train Batch: 21000, Loss: 0.0561
# Train Batch: 21100, Loss: 0.0000
# Train Batch: 21200, Loss: 0.0000
# Train Batch: 21300, Loss: 0.0000
# Train Batch: 21400, Loss: 0.0000
# Train Batch: 21500, Loss: 0.0000
# Train Batch: 21600, Loss: 0.0000
# Train Batch: 21700, Loss: 2.9960
# Train Batch: 21800, Loss: 0.0000
# Train Batch: 21900, Loss: 0.0000
# Train Batch: 22000, Loss: 0.0048
# Train Batch: 22100, Loss: 0.0134
# Train Batch: 22200, Loss: 0.0009
# Train Batch: 22300, Loss: 0.0000
# Train Batch: 22400, Loss: 0.1439
# Train Batch: 22500, Loss: 0.0000
# Train Batch: 22600, Loss: 0.0000
# Train Batch: 22700, Loss: 0.0000
# Train Batch: 22800, Loss: 0.0057
# Train Batch: 22900, Loss: 0.0000
# Train Batch: 23000, Loss: 0.0000
# Train Batch: 23100, Loss: 1.8232
# Train Batch: 23200, Loss: 0.0000
# Train Batch: 23300, Loss: 0.0000
# Train Batch: 23400, Loss: 15.7207
# Train Batch: 23500, Loss: 0.0000
# Train Batch: 23600, Loss: 0.0005
# Train Batch: 23700, Loss: 0.0000
# Train Batch: 23800, Loss: 0.0000
# Train Batch: 23900, Loss: 0.0000
# Train Batch: 24000, Loss: 0.0000
# Train Batch: 24100, Loss: 0.0000
# Train Batch: 24200, Loss: 0.0000
# Train Batch: 24300, Loss: 1.5853
# Train Batch: 24400, Loss: 0.0000
# Train Batch: 24500, Loss: 0.0000
# Train Batch: 24600, Loss: 0.0000
# Train Batch: 24700, Loss: 0.0000
# Train Batch: 24800, Loss: 0.0000
# Train Batch: 24900, Loss: 0.0007
# Train Batch: 25000, Loss: 0.0729
# Train Batch: 25100, Loss: 0.0592
# Train Batch: 25200, Loss: 0.0000
# Train Batch: 25300, Loss: 0.0000
# Train Batch: 25400, Loss: 0.0168
# Train Batch: 25500, Loss: 0.0000
# Train Batch: 25600, Loss: 0.0000
# Train Batch: 25700, Loss: 0.0000
# Train Batch: 25800, Loss: 5.7449
# Train Batch: 25900, Loss: 0.1192
# Train Batch: 26000, Loss: 0.0027
# Train Batch: 26100, Loss: 0.0000
# ...
# Train Batch: 11600, Loss: 0.5436
# Train Batch: 11700, Loss: 0.2274
# Train Batch: 11800, Loss: 0.0000
# Train Batch: 11900, Loss: 0.4443
# Train Batch: 12000, Loss: 4.1361
# Train Batch: 12100, Loss: 0.0000
# Train Batch: 12200, Loss: 0.0003
# Train Batch: 12300, Loss: 0.0000
# Train Batch: 12400, Loss: 0.0000
# Train Batch: 12500, Loss: 0.0000
# Train Batch: 12600, Loss: 0.0430
# Train Batch: 12700, Loss: 0.0000
# Train Batch: 12800, Loss: 0.0000
# Train Batch: 12900, Loss: 1.6763
# Train Batch: 13000, Loss: 0.0001
# Train Batch: 13100, Loss: 0.0055
# Train Batch: 13200, Loss: 0.0000
# Train Batch: 13300, Loss: 0.0000
# Train Batch: 13400, Loss: 0.0001
# Train Batch: 13500, Loss: 0.0021
# Train Batch: 13600, Loss: 0.0000
# Train Batch: 13700, Loss: 0.0000
# Train Batch: 13800, Loss: 0.0000
# Train Batch: 13900, Loss: 0.0173
# Train Batch: 14000, Loss: 0.0000
# Train Batch: 14100, Loss: 0.0001
# Train Batch: 14200, Loss: 0.0000
# Train Batch: 14300, Loss: 0.0000
# Train Batch: 14400, Loss: 0.0000
# Train Batch: 14500, Loss: 0.0661
# Train Batch: 14600, Loss: 0.0000
# Train Batch: 14700, Loss: 5.0226
# Train Batch: 14800, Loss: 0.0000
# Train Batch: 14900, Loss: 0.0000
# Train Batch: 15000, Loss: 0.0004
# Train Batch: 15100, Loss: 0.0165
# Train Batch: 15200, Loss: 0.0000
# Train Batch: 15300, Loss: 0.0000
# Train Batch: 15400, Loss: 0.1124
# Train Batch: 15500, Loss: 2.3677
# Train Batch: 15600, Loss: 0.0000
# Train Batch: 15700, Loss: 0.0000
# Train Batch: 15800, Loss: 0.0000
# Train Batch: 15900, Loss: 0.0000
# Train Batch: 16000, Loss: 0.0000
# Train Batch: 16100, Loss: 0.8377
# Train Batch: 16200, Loss: 0.0001
# Train Batch: 16300, Loss: 0.0000
# Train Batch: 16400, Loss: 0.0000
# Train Batch: 16500, Loss: 0.0000
# Train Batch: 16600, Loss: 0.0101
# Train Batch: 16700, Loss: 0.0001
# Train Batch: 16800, Loss: 0.0000
# Train Batch: 16900, Loss: 0.0730
# Train Batch: 17000, Loss: 0.0000
# Train Batch: 17100, Loss: 0.0000
# Train Batch: 17200, Loss: 1.8727
# Train Batch: 17300, Loss: 0.0001
# Train Batch: 17400, Loss: 12.2464
# Train Batch: 17500, Loss: 0.0008
# Train Batch: 17600, Loss: 0.0000
# Train Batch: 17700, Loss: 0.0000
# Train Batch: 17800, Loss: 0.0000
# Train Batch: 17900, Loss: 0.0003
# Train Batch: 18000, Loss: 0.0106
# Train Batch: 18100, Loss: 0.0000
# Train Batch: 18200, Loss: 0.0000
# Train Batch: 18300, Loss: 0.0000
# Train Batch: 18400, Loss: 0.0000
# Train Batch: 18500, Loss: 0.0071
# Train Batch: 18600, Loss: 0.0000
# Train Batch: 18700, Loss: 0.0780
# Train Batch: 18800, Loss: 0.0000
# Train Batch: 18900, Loss: 0.1598
# Train Batch: 19000, Loss: 0.0011
# Train Batch: 19100, Loss: 0.0000
# Train Batch: 19200, Loss: 0.0000
# Train Batch: 19300, Loss: 0.0000
# Train Batch: 19400, Loss: 0.0000
# Train Batch: 19500, Loss: 0.0000
# Train Batch: 19600, Loss: 0.0085
# Train Batch: 19700, Loss: 0.0032
# Train Batch: 19800, Loss: 0.0000
# Train Batch: 19900, Loss: 0.0000
# Train Batch: 20000, Loss: 0.0000
# Train Batch: 20100, Loss: 0.0024
# Train Batch: 20200, Loss: 0.0000
# Train Batch: 20300, Loss: 0.0024
# Train Batch: 20400, Loss: 0.0000
# Train Batch: 20500, Loss: 0.0000
# Train Batch: 20600, Loss: 0.0212
# Train Batch: 20700, Loss: 0.0000
# Train Batch: 20800, Loss: 0.0173
# Train Batch: 20900, Loss: 0.0002
# Train Batch: 21000, Loss: 0.0155
# Train Batch: 21100, Loss: 0.0011
# Train Batch: 21200, Loss: 0.0000
# Train Batch: 21300, Loss: 0.0000
# Train Batch: 21400, Loss: 0.0000
# Train Batch: 21500, Loss: 0.0000
# Train Batch: 21600, Loss: 0.0000
# Train Batch: 21700, Loss: 3.4137
# Train Batch: 21800, Loss: 0.0016
# Train Batch: 21900, Loss: 0.0000
# Train Batch: 22000, Loss: 0.0000
# Train Batch: 22100, Loss: 0.0085
# Train Batch: 22200, Loss: 0.0970
# Train Batch: 22300, Loss: 0.0000
# Train Batch: 22400, Loss: 0.2207
# Train Batch: 22500, Loss: 0.0047
# Train Batch: 22600, Loss: 0.0000
# Train Batch: 22700, Loss: 0.0000
# Train Batch: 22800, Loss: 0.0001
# Train Batch: 22900, Loss: 0.0000
# Train Batch: 23000, Loss: 0.0000
# Train Batch: 23100, Loss: 0.0000
# Train Batch: 23200, Loss: 0.0000
# Train Batch: 23300, Loss: 0.0019
# Train Batch: 23400, Loss: 2.1572
# Train Batch: 23500, Loss: 0.0000
# Train Batch: 23600, Loss: 0.0000
# Train Batch: 23700, Loss: 0.0000
# Train Batch: 23800, Loss: 0.1284
# Train Batch: 23900, Loss: 0.0000
# Train Batch: 24000, Loss: 0.0000
# Train Batch: 24100, Loss: 0.0000
# Train Batch: 24200, Loss: 0.0000
# Train Batch: 24300, Loss: 0.0177
# Train Batch: 24400, Loss: 0.0000
# Train Batch: 24500, Loss: 0.0000
# Train Batch: 24600, Loss: 0.0000
# Train Batch: 24700, Loss: 0.0000
# Train Batch: 24800, Loss: 0.0000
# Train Batch: 24900, Loss: 0.0482
# Train Batch: 25000, Loss: 0.0000
# Train Batch: 25100, Loss: 0.0351
# Train Batch: 25200, Loss: 0.0004
# Train Batch: 25300, Loss: 0.0000
# Train Batch: 25400, Loss: 0.0002
# Train Batch: 25500, Loss: 0.0000
# Train Batch: 25600, Loss: 0.0000
# Train Batch: 25700, Loss: 0.0000
# Train Batch: 25800, Loss: 1.4614
# Train Batch: 25900, Loss: 0.0057
# Train Batch: 26000, Loss: 0.0000
# Train Batch: 26100, Loss: 0.0000
# Train Batch: 26200, Loss: 0.0000
# Train Batch: 26300, Loss: 1.8487
# Train Batch: 26400, Loss: 0.0000
# Train Batch: 26500, Loss: 0.0000
# Train Batch: 26600, Loss: 3.3049
# Train Batch: 26700, Loss: 0.0000
# Train Batch: 26800, Loss: 0.0000
# Train Batch: 26900, Loss: 0.6526
# Train Batch: 27000, Loss: 0.2455
# Train Batch: 27100, Loss: 0.0004
# Train Batch: 27200, Loss: 1.8136
# Train Batch: 27300, Loss: 0.0000
# Train Batch: 27400, Loss: 0.0000
# Train Batch: 27500, Loss: 0.0000
# Train Batch: 27600, Loss: 0.0000
# Train Batch: 27700, Loss: 0.0459
# Train Batch: 27800, Loss: 0.0004
# Train Batch: 27900, Loss: 0.0001
# Train Batch: 28000, Loss: 0.0000
# Train Batch: 28100, Loss: 0.0000
# Train Batch: 28200, Loss: 0.0221
# Train Batch: 28300, Loss: 0.0000
# Train Batch: 28400, Loss: 0.0000
# Train Batch: 28500, Loss: 0.0000
# Train Batch: 28600, Loss: 0.0000
# Train Batch: 28700, Loss: 0.0002
# Train Batch: 28800, Loss: 0.0000
# Train Batch: 28900, Loss: 0.0019
# Train Batch: 29000, Loss: 0.0758
# Train Batch: 29100, Loss: 0.0000
# Train Batch: 29200, Loss: 0.0008
# Train Batch: 29300, Loss: 0.0001
# Train Batch: 29400, Loss: 0.0000
# Train Batch: 29500, Loss: 0.0008
# Train Batch: 29600, Loss: 0.0000
# Train Batch: 29700, Loss: 0.0100
# Train Batch: 29800, Loss: 0.0000
# Train Batch: 29900, Loss: 0.0000
# Train Batch: 30000, Loss: 0.0000
# Train Batch: 30100, Loss: 0.0000
# Train Batch: 30200, Loss: 0.0000
# Train Batch: 30300, Loss: 0.0000
# Train Batch: 30400, Loss: 0.0000
# Train Batch: 30500, Loss: 0.0000
# Train Batch: 30600, Loss: 0.4149
# Train Batch: 30700, Loss: 0.0000
# Train Batch: 30800, Loss: 0.0000
# Train Batch: 30900, Loss: 2.6118
# Train Batch: 31000, Loss: 0.0000
# Train Batch: 31100, Loss: 0.0044
# Train Batch: 31200, Loss: 1.8188
# Train Batch: 31300, Loss: 0.0000
# Train Batch: 31400, Loss: 0.0000
# Train Batch: 31500, Loss: 0.4365
# Train Batch: 31600, Loss: 8.0306
# Train Batch: 31700, Loss: 0.0092
# Train Batch: 31800, Loss: 0.0054
# Train Batch: 31900, Loss: 0.0000
# Train Batch: 32000, Loss: 0.0027
# Train Batch: 32100, Loss: 0.5214
# Train Batch: 32200, Loss: 0.0000
# Train Batch: 32300, Loss: 0.0000
# Train Batch: 32400, Loss: 0.0001
# Train Batch: 32500, Loss: 0.0025
# Train Batch: 32600, Loss: 0.0000
# Train Batch: 32700, Loss: 0.0000
# Train Batch: 32800, Loss: 0.0000
# Train Batch: 32900, Loss: 0.0000
# Train Batch: 33000, Loss: 0.0002
# Train Batch: 33100, Loss: 0.0000
# Train Batch: 33200, Loss: 0.0000
# Train Batch: 33300, Loss: 0.0000
# Train Batch: 33400, Loss: 0.0000
# Train Batch: 33500, Loss: 0.0000
# Train Batch: 33600, Loss: 0.0000
# Train Batch: 33700, Loss: 0.0000
# Train Batch: 33800, Loss: 0.0000
# Train Batch: 33900, Loss: 4.4133
# Train Batch: 34000, Loss: 0.0000
# Train Batch: 34100, Loss: 0.0086
# Train Batch: 34200, Loss: 0.0000
# Train Batch: 34300, Loss: 0.5614
# Train Batch: 34400, Loss: 0.0000
# Train Batch: 34500, Loss: 6.0406
# Train Batch: 34600, Loss: 0.0000
# Train Batch: 34700, Loss: 0.0370
# Train Batch: 34800, Loss: 7.3082
# Train Batch: 34900, Loss: 0.0029
# Train Batch: 35000, Loss: 0.0000
# Train Batch: 35100, Loss: 0.0001
# Train Batch: 35200, Loss: 0.0005
# Train Batch: 35300, Loss: 0.1245
# Train Batch: 35400, Loss: 0.0000
# Train Batch: 35500, Loss: 0.0000
# Train Batch: 35600, Loss: 0.0000
# Train Batch: 35700, Loss: 0.0000
# Train Batch: 35800, Loss: 0.0000
# Train Batch: 35900, Loss: 0.0000
# Train Batch: 36000, Loss: 0.0000
# Train Batch: 36100, Loss: 1.5096
# Train Batch: 36200, Loss: 0.0097
# Train Batch: 36300, Loss: 0.0054
# Train Batch: 36400, Loss: 0.0003
# Train Batch: 36500, Loss: 0.0010
# Train Batch: 36600, Loss: 0.0601
# Train Batch: 36700, Loss: 0.0063
# Train Batch: 36800, Loss: 0.0000
# Train Batch: 36900, Loss: 1.0016
# Train Batch: 37000, Loss: 0.0000
# Train Batch: 37100, Loss: 0.8827
# Train Batch: 37200, Loss: 0.0000
# Train Batch: 37300, Loss: 0.0000
# Train Batch: 37400, Loss: 0.0177
# Train Batch: 37500, Loss: 0.0000
# Train Batch: 37600, Loss: 0.0000
# Train Batch: 37700, Loss: 0.0000
# Train Batch: 37800, Loss: 0.0000
# Train Batch: 37900, Loss: 0.0000
# Train Batch: 38000, Loss: 0.0046
# Train Batch: 38100, Loss: 0.0000
# Train Batch: 38200, Loss: 0.0000
# Train Batch: 38300, Loss: 0.0128
# Train Batch: 38400, Loss: 0.0000
# Train Batch: 38500, Loss: 0.0000
# Train Batch: 38600, Loss: 0.0010
# Train Batch: 38700, Loss: 2.3576
# Train Batch: 38800, Loss: 0.4653
# Train Batch: 38900, Loss: 0.0000
# Train Batch: 39000, Loss: 0.0035
# Train Batch: 39100, Loss: 0.0000
# Train Batch: 39200, Loss: 0.0000
# Train Batch: 39300, Loss: 0.0000
# Train Batch: 39400, Loss: 0.0000
# Train Batch: 39500, Loss: 3.8122
# Train Batch: 39600, Loss: 1.8638
# Train Batch: 39700, Loss: 0.0000
# Train Batch: 39800, Loss: 0.0000
# Train Batch: 39900, Loss: 0.0000
# Train Batch: 40000, Loss: 0.0000
# Train Batch: 40100, Loss: 0.0000
# Train Batch: 40200, Loss: 0.0000
# Train Batch: 40300, Loss: 0.0000
# Train Batch: 40400, Loss: 0.0000
# Train Batch: 40500, Loss: 0.0000
# Train Batch: 40600, Loss: 0.0042
# Train Batch: 40700, Loss: 0.0014
# Train Batch: 40800, Loss: 0.0000
# Train Batch: 40900, Loss: 0.0662
# Train Batch: 41000, Loss: 0.0000
# Train Batch: 41100, Loss: 0.0000
# Train Batch: 41200, Loss: 0.0001
# Train Batch: 41300, Loss: 0.0005
# Train Batch: 41400, Loss: 0.0146
# Train Batch: 41500, Loss: 0.0121
# Train Batch: 41600, Loss: 0.0000
# Train Batch: 41700, Loss: 0.0090
# Train Batch: 41800, Loss: 0.0001
# Train Batch: 41900, Loss: 0.0000
# Train Batch: 42000, Loss: 0.0000
# Train Batch: 42100, Loss: 0.0000
# Train Batch: 42200, Loss: 0.0000
# Train Batch: 42300, Loss: 0.0000
# Train Batch: 42400, Loss: 0.0000
# Train Batch: 42500, Loss: 0.0000
# Train Batch: 42600, Loss: 0.0000
# Train Batch: 42700, Loss: 0.0000
# Train Batch: 42800, Loss: 0.0000
# Train Batch: 42900, Loss: 0.0214
# Train Batch: 43000, Loss: 0.0000
# Train Batch: 43100, Loss: 0.0000
# Train Batch: 43200, Loss: 0.0032
# Train Batch: 43300, Loss: 0.0000
# Train Batch: 43400, Loss: 0.0000
# Train Batch: 43500, Loss: 0.0000
# Train Batch: 43600, Loss: 0.0326
# Train Batch: 43700, Loss: 0.1616
# Train Batch: 43800, Loss: 0.0000
# Train Batch: 43900, Loss: 0.0247
# Train Batch: 44000, Loss: 0.0000
# Train Batch: 44100, Loss: 5.3809
# Train Batch: 44200, Loss: 0.0231
# Train Batch: 44300, Loss: 0.0284
# Train Batch: 44400, Loss: 0.0053
# Train Batch: 44500, Loss: 0.0000
# Train Batch: 44600, Loss: 0.0059
# Train Batch: 44700, Loss: 0.0000
# Train Batch: 44800, Loss: 0.0000
# Train Batch: 44900, Loss: 0.0000
# Train Batch: 45000, Loss: 0.0000
# Train Batch: 45100, Loss: 0.0000
# Train Batch: 45200, Loss: 0.0000
# Train Batch: 45300, Loss: 0.0000
# Train Batch: 45400, Loss: 0.0000
# Train Batch: 45500, Loss: 0.0661
# Train Batch: 45600, Loss: 0.0000
# Train Batch: 45700, Loss: 0.0039
# Train Batch: 45800, Loss: 0.0000
# Train Batch: 45900, Loss: 0.0000
# Train Batch: 46000, Loss: 0.0018
# Train Batch: 46100, Loss: 0.0305
# Train Batch: 46200, Loss: 0.0001
# Train Batch: 46300, Loss: 0.6293
# Train Batch: 46400, Loss: 0.0000
# Train Batch: 46500, Loss: 0.0000
# Train Batch: 46600, Loss: 0.0000
# Train Batch: 46700, Loss: 0.0000
# Train Batch: 46800, Loss: 0.0000
# Train Batch: 46900, Loss: 0.0000
# Train Batch: 47000, Loss: 0.0001
# Train Batch: 47100, Loss: 0.1773
# Train Batch: 47200, Loss: 0.0177
# Train Batch: 47300, Loss: 0.0000
# Train Batch: 47400, Loss: 0.0000
# Train Batch: 47500, Loss: 0.0000
# Train Batch: 47600, Loss: 13.6681
# Train Batch: 47700, Loss: 0.0000
# Train Batch: 47800, Loss: 0.0000
# Train Batch: 47900, Loss: 0.0000
# Train Batch: 48000, Loss: 0.0049
# Train Batch: 48100, Loss: 0.0000
# Train Batch: 48200, Loss: 0.0000
# Train Batch: 48300, Loss: 0.0000
# Train Batch: 48400, Loss: 0.0000
# Train Batch: 48500, Loss: 0.0066
# Train Batch: 48600, Loss: 0.0000
# Train Batch: 48700, Loss: 0.0000
# Train Batch: 48800, Loss: 0.1329
# Train Batch: 48900, Loss: 0.0000
# Train Batch: 49000, Loss: 0.0000
# Train Batch: 49100, Loss: 0.0000
# Train Batch: 49200, Loss: 0.0651
# Train Batch: 49300, Loss: 1.8806
# Train Batch: 49400, Loss: 0.0224
# Train Batch: 49500, Loss: 0.0000
# Train Batch: 49600, Loss: 0.0000
# Train Batch: 49700, Loss: 0.0467
# Train Batch: 49800, Loss: 0.0000
# Train Batch: 49900, Loss: 0.0000
# Train Batch: 50000, Loss: 0.0000
# Train Batch: 50100, Loss: 0.0000
# Train Batch: 50200, Loss: 0.0000
# Train Batch: 50300, Loss: 0.0000
# Train Batch: 50400, Loss: 0.0000
# Train Batch: 50500, Loss: 0.4790
# Train Batch: 50600, Loss: 0.0000
# Train Batch: 50700, Loss: 0.1743
# Train Batch: 50800, Loss: 0.0001
# Train Batch: 50900, Loss: 0.0000
# Train Batch: 51000, Loss: 0.0000
# Train Batch: 51100, Loss: 0.0000
# Train Batch: 51200, Loss: 0.8666
# Train Batch: 51300, Loss: 0.0002
# Train Batch: 51400, Loss: 0.0024
# Train Batch: 51500, Loss: 0.0000
# Train Batch: 51600, Loss: 0.0791
# Train Batch: 51700, Loss: 0.0037
# Train Batch: 51800, Loss: 0.0000
# Train Batch: 51900, Loss: 0.0000
# Train Batch: 52000, Loss: 0.0024
# Train Batch: 52100, Loss: 0.0163
# Train Batch: 52200, Loss: 0.0000
# Train Batch: 52300, Loss: 0.0000
# Train Batch: 52400, Loss: 0.0000
# Train Batch: 52500, Loss: 0.0000
# Train Batch: 52600, Loss: 0.1092
# Train Batch: 52700, Loss: 0.0001
# Train Batch: 52800, Loss: 2.8581
# Train Batch: 52900, Loss: 0.0025
# Train Batch: 53000, Loss: 0.0000
# Train Batch: 53100, Loss: 0.0000
# Train Batch: 53200, Loss: 0.0000
# Train Batch: 53300, Loss: 0.0039
# Train Batch: 53400, Loss: 0.0000
# Train Batch: 53500, Loss: 0.0000
# Train Batch: 53600, Loss: 0.0005
# Train Batch: 53700, Loss: 0.0000
# Train Batch: 53800, Loss: 0.0000
# Train Batch: 53900, Loss: 0.0001
# Train Batch: 54000, Loss: 0.0000
# Train Batch: 54100, Loss: 0.0002
# Train Batch: 54200, Loss: 0.0000
# Train Batch: 54300, Loss: 0.0000
# Train Batch: 54400, Loss: 0.0261
# Train Batch: 54500, Loss: 0.0000
# Train Batch: 54600, Loss: 0.0000
# Train Batch: 54700, Loss: 0.0000
# Train Batch: 54800, Loss: 0.0000
# Train Batch: 54900, Loss: 0.0000
# Train Batch: 55000, Loss: 0.0000
# Train Batch: 55100, Loss: 0.0004
# Train Batch: 55200, Loss: 0.0000
# Train Batch: 55300, Loss: 0.0000
# Train Batch: 55400, Loss: 0.0000
# Train Batch: 55500, Loss: 0.0000
# Train Batch: 55600, Loss: 0.0000
# Train Batch: 55700, Loss: 0.0000
# Train Batch: 55800, Loss: 0.0000
# Train Batch: 55900, Loss: 0.0001
# Train Batch: 56000, Loss: 0.0000
# Train Batch: 56100, Loss: 0.0000
# Train Batch: 56200, Loss: 0.0000
# Train Batch: 56300, Loss: 0.0001
# Train Batch: 56400, Loss: 0.0000
# Train Batch: 56500, Loss: 0.0000
# Train Batch: 56600, Loss: 0.0069
# Train Batch: 56700, Loss: 0.0000
# Train Batch: 56800, Loss: 1.0302
# Train Batch: 56900, Loss: 0.0000
# Train Batch: 57000, Loss: 0.0000
# Train Batch: 57100, Loss: 0.1081
# Train Batch: 57200, Loss: 0.0000
# Train Batch: 57300, Loss: 0.0000
# Train Batch: 57400, Loss: 0.0000
# Train Batch: 57500, Loss: 0.0000
# Train Batch: 57600, Loss: 0.0000
# Train Batch: 57700, Loss: 0.0000
# Train Batch: 57800, Loss: 0.0000
# Train Batch: 57900, Loss: 0.0000
# Train Batch: 58000, Loss: 0.0000
# Train Batch: 58100, Loss: 0.0000
# Train Batch: 58200, Loss: 0.0000
# Train Batch: 58300, Loss: 0.0000
# Train Batch: 58400, Loss: 0.0000
# Train Batch: 58500, Loss: 0.0000
# Train Batch: 58600, Loss: 0.0000
# Train Batch: 58700, Loss: 0.0000
# Train Batch: 58800, Loss: 0.0000
# Train Batch: 58900, Loss: 0.0187
# Train Batch: 59000, Loss: 0.0000
# Train Batch: 59100, Loss: 0.0000
# Train Batch: 59200, Loss: 0.0000
# Train Batch: 59300, Loss: 0.0079
# Train Batch: 59400, Loss: 0.0000
# Train Batch: 59500, Loss: 0.0000
# Train Batch: 59600, Loss: 0.0000
# Train Batch: 59700, Loss: 0.0000
# Train Batch: 59800, Loss: 0.0000
# Train Batch: 59900, Loss: 0.0003
# Test Accuracy: 92.13%
